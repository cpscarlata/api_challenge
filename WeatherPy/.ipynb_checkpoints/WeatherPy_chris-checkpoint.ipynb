# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
from scipy.stats import linregress

# OpenWeatherMap API key
api_key = "673ef970d036accfc58bb492f6f3ea32"

# weather_api_key = "3974be9fa6e0d0ba48004fb47c9abbeb"

# Import the OpenWeatherMap API key
# from api_keys import weather_api_key
# print(weather_api_key)

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = 'cities.csv'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

saved_lats = []
saved_longs = []

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    #also add estimated latitude and longitude
    if city not in cities:
        cities.append(city)
        saved_lats.append(lat_lng[0])
        saved_longs.append(lat_lng[1])
        
# print(citipy.nearest_city(0, 0).keys())

# Print the city count to confirm sufficient count
print("{} cities have been identified to poll for weather".format(len(cities)))

city_list = pd.DataFrame({"City":cities, "Approx. Latitude":saved_lats, "Approx. Longitude":saved_longs})
# city_list = pd.DataFrame({"City":cities})

#save to a csv (for reference - can compare estimated coordinates to actual coordinates if there is time, which cannot be done
#easily with citipy because the references only go one way -> approx. coordinates to city name, not city name to actual 
#coordinates)
city_list.to_csv("./worldcities.csv")
city_list.head()
# Out:
# 579 cities have been identified to poll for weather
#                 City  Approx. Latitude  Approx. Longitude
# 0          adamstown        -48.939972        -140.329306
# 1     puerto natales        -49.175987         -86.645890
# 2            la mira         12.821253        -105.601749
# 3             bethel         77.827386        -160.302875
# 4  port-aux-francais        -47.657419          86.620120

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | la mira
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | stanley
# Processing Record 8 of Set 1 | isafjordur
# Processing Record 9 of Set 1 | hawaiian paradise park
# Processing Record 10 of Set 1 | wonsan
# Processing Record 11 of Set 1 | cromer
# Processing Record 12 of Set 1 | anadyr
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | chinde
# Processing Record 15 of Set 1 | klyuchi
# Processing Record 16 of Set 1 | afaahiti
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | hadibu
# Processing Record 20 of Set 1 | quinhamel
# Processing Record 21 of Set 1 | waitangi
# Processing Record 22 of Set 1 | ladismith
# City not found. Skipping...
# Processing Record 23 of Set 1 | al azraq ash shamali
# City not found. Skipping...
# Processing Record 24 of Set 1 | luderitz
# Processing Record 25 of Set 1 | corowa
# Processing Record 26 of Set 1 | geraldton
# Processing Record 27 of Set 1 | port mathurin
# Processing Record 28 of Set 1 | edinburgh of the seven seas
# Processing Record 29 of Set 1 | las toscas
# Processing Record 30 of Set 1 | trelissac
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 33 of Set 1 | kailua-kona
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | novodvinsk
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | yeppoon
# Processing Record 38 of Set 1 | happy valley-goose bay
# Processing Record 39 of Set 1 | santana
# Processing Record 40 of Set 1 | broken hill
# Processing Record 41 of Set 1 | qaqortoq
# Processing Record 42 of Set 1 | jamaame
# Processing Record 43 of Set 1 | coquimbo
# Processing Record 44 of Set 1 | lata
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | oamaru
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | invercargill
# Processing Record 50 of Set 1 | bonthe
# Processing Record 0 of Set 2 | bilibino
# Processing Record 1 of Set 2 | port lincoln
# Processing Record 2 of Set 2 | takamaka
# City not found. Skipping...
# Processing Record 3 of Set 2 | ancud
# Processing Record 4 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | ust'-kulom
# Processing Record 7 of Set 2 | tamanrasset
# Processing Record 8 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 2 | blackmans bay
# Processing Record 10 of Set 2 | reggane
# Processing Record 11 of Set 2 | tura
# Processing Record 12 of Set 2 | shangri-la
# City not found. Skipping...
# Processing Record 13 of Set 2 | iqaluit
# Processing Record 14 of Set 2 | sur
# Processing Record 15 of Set 2 | mammoth lakes
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | whitehorse
# Processing Record 18 of Set 2 | tual
# Processing Record 19 of Set 2 | haiku-pauwela
# Processing Record 20 of Set 2 | minas de marcona
# Processing Record 21 of Set 2 | uturoa
# Processing Record 22 of Set 2 | isangel
# Processing Record 23 of Set 2 | samitah
# Processing Record 24 of Set 2 | anzio
# Processing Record 25 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 2 | weno
# Processing Record 27 of Set 2 | quellon
# Processing Record 28 of Set 2 | alibag
# Processing Record 29 of Set 2 | tulun
# Processing Record 30 of Set 2 | santa marta de ortigueira
# Processing Record 31 of Set 2 | badiyah
# Processing Record 32 of Set 2 | batman
# Processing Record 33 of Set 2 | margaret river
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | inhambane
# Processing Record 36 of Set 2 | ishikawa
# Processing Record 37 of Set 2 | collie
# Processing Record 38 of Set 2 | hasaki
# Processing Record 39 of Set 2 | costa teguise
# City not found. Skipping...
# Processing Record 40 of Set 2 | gejiu
# Processing Record 41 of Set 2 | san antonio de pale
# Processing Record 42 of Set 2 | sesheke
# Processing Record 43 of Set 2 | le trait
# Processing Record 44 of Set 2 | sisak
# Processing Record 45 of Set 2 | qamdo
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | ngaoundere
# Processing Record 48 of Set 2 | kerikeri
# Processing Record 49 of Set 2 | nova mayachka
# Processing Record 0 of Set 3 | bubaque
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | st. john's
# Processing Record 4 of Set 3 | jackson
# Processing Record 5 of Set 3 | kununurra
# Processing Record 6 of Set 3 | ojinaga
# Processing Record 7 of Set 3 | opuwo
# Processing Record 8 of Set 3 | ilulissat
# Processing Record 9 of Set 3 | necochea
# Processing Record 10 of Set 3 | mariakani
# Processing Record 11 of Set 3 | nova sintra
# Processing Record 12 of Set 3 | kzyltu
# Processing Record 13 of Set 3 | kataragama
# City not found. Skipping...
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | shanhecun
# Processing Record 16 of Set 3 | senillosa
# Processing Record 17 of Set 3 | whakatane
# Processing Record 18 of Set 3 | sault ste. marie
# Processing Record 19 of Set 3 | mount isa
# Processing Record 20 of Set 3 | sitka
# Processing Record 21 of Set 3 | port alberni
# Processing Record 22 of Set 3 | west island
# Processing Record 23 of Set 3 | byford
# Processing Record 24 of Set 3 | chonchi
# Processing Record 25 of Set 3 | port blair
# Processing Record 26 of Set 3 | yelizovo
# Processing Record 27 of Set 3 | yellowknife
# Processing Record 28 of Set 3 | ikedacho
# Processing Record 29 of Set 3 | aasiaat
# Processing Record 30 of Set 3 | prado
# Processing Record 31 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 3 | maamba
# Processing Record 33 of Set 3 | pamandzi
# Processing Record 34 of Set 3 | beteza
# City not found. Skipping...
# Processing Record 35 of Set 3 | mar del plata
# Processing Record 36 of Set 3 | kasese
# Processing Record 37 of Set 3 | cill airne
# Processing Record 38 of Set 3 | lompoc
# Processing Record 39 of Set 3 | constantia
# Processing Record 40 of Set 3 | mount pearl
# Processing Record 41 of Set 3 | wanzleben
# Processing Record 42 of Set 3 | port glaud
# City not found. Skipping...
# Processing Record 43 of Set 3 | lebu
# Processing Record 44 of Set 3 | susuman
# Processing Record 45 of Set 3 | christchurch
# Processing Record 46 of Set 3 | anloga
# Processing Record 47 of Set 3 | ola
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | ilanskiy
# Processing Record 0 of Set 4 | olonkinbyen
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | muisne
# Processing Record 3 of Set 4 | fort st. john
# Processing Record 4 of Set 4 | codrington
# Processing Record 5 of Set 4 | popondetta
# Processing Record 6 of Set 4 | hamilton
# Processing Record 7 of Set 4 | palu
# Processing Record 8 of Set 4 | wenchang
# Processing Record 9 of Set 4 | lugazi
# Processing Record 10 of Set 4 | jalai nur
# Processing Record 11 of Set 4 | buka
# Processing Record 12 of Set 4 | yallahs
# Processing Record 13 of Set 4 | macia
# Processing Record 14 of Set 4 | anabar
# City not found. Skipping...
# Processing Record 15 of Set 4 | egilsstadir
# Processing Record 16 of Set 4 | manokwari
# Processing Record 17 of Set 4 | talnakh
# Processing Record 18 of Set 4 | ghadamis
# Processing Record 19 of Set 4 | laguna
# Processing Record 20 of Set 4 | college
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | gadzhiyevo
# Processing Record 23 of Set 4 | yeed
# Processing Record 24 of Set 4 | melchor de mencos
# Processing Record 25 of Set 4 | fort stockton
# Processing Record 26 of Set 4 | calvinia
# Processing Record 27 of Set 4 | saratamata
# City not found. Skipping...
# Processing Record 28 of Set 4 | rabaul
# Processing Record 29 of Set 4 | dwarka
# Processing Record 30 of Set 4 | chilecito
# Processing Record 31 of Set 4 | guerrero negro
# Processing Record 32 of Set 4 | gura vitioarei
# Processing Record 33 of Set 4 | enewetak
# Processing Record 34 of Set 4 | thompson
# Processing Record 35 of Set 4 | nabire
# Processing Record 36 of Set 4 | alaghsas
# Processing Record 37 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 38 of Set 4 | badger
# Processing Record 39 of Set 4 | kota bharu
# Processing Record 40 of Set 4 | ust'-uda
# Processing Record 41 of Set 4 | filadelfia
# Processing Record 42 of Set 4 | novoishimskiy
# Processing Record 43 of Set 4 | nar'yan-mar
# Processing Record 44 of Set 4 | port alfred
# Processing Record 45 of Set 4 | bardai
# Processing Record 46 of Set 4 | inari
# Processing Record 47 of Set 4 | hammerfest
# Processing Record 48 of Set 4 | posto fiscal rolim de moura
# Processing Record 49 of Set 4 | nsanje
# Processing Record 0 of Set 5 | santa cruz
# Processing Record 1 of Set 5 | alta
# Processing Record 2 of Set 5 | puerto colombia
# Processing Record 3 of Set 5 | wailua homesteads
# Processing Record 4 of Set 5 | bamboo flat
# Processing Record 5 of Set 5 | ust-nera
# Processing Record 6 of Set 5 | brokopondo
# Processing Record 7 of Set 5 | chamrajnagar
# Processing Record 8 of Set 5 | paita
# Processing Record 9 of Set 5 | iskateley
# Processing Record 10 of Set 5 | mugia
# Processing Record 11 of Set 5 | aliveri
# Processing Record 12 of Set 5 | marsabit
# Processing Record 13 of Set 5 | colonia
# Processing Record 14 of Set 5 | hami
# Processing Record 15 of Set 5 | newman
# Processing Record 16 of Set 5 | vilyuchinsk
# Processing Record 17 of Set 5 | quelimane
# Processing Record 18 of Set 5 | prachuap khiri khan
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | tolanaro
# Processing Record 21 of Set 5 | tazacorte
# Processing Record 22 of Set 5 | mana
# Processing Record 23 of Set 5 | ghanzi
# Processing Record 24 of Set 5 | dryden
# Processing Record 25 of Set 5 | papatowai
# Processing Record 26 of Set 5 | itoman
# Processing Record 27 of Set 5 | todos santos
# Processing Record 28 of Set 5 | nogliki
# Processing Record 29 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 30 of Set 5 | arkhangel'sk
# Processing Record 31 of Set 5 | trapani
# Processing Record 32 of Set 5 | borkum
# Processing Record 33 of Set 5 | galesong
# Processing Record 34 of Set 5 | mbuji-mayi
# Processing Record 35 of Set 5 | celestun
# Processing Record 36 of Set 5 | port said
# Processing Record 37 of Set 5 | sao joao da barra
# Processing Record 38 of Set 5 | saint-pierre
# Processing Record 39 of Set 5 | mananara
# Processing Record 40 of Set 5 | pyt-yakh
# Processing Record 41 of Set 5 | anna regina
# Processing Record 42 of Set 5 | talodi
# Processing Record 43 of Set 5 | havre
# Processing Record 44 of Set 5 | tsiombe
# Processing Record 45 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 46 of Set 5 | bayganin
# Processing Record 47 of Set 5 | qapqal
# City not found. Skipping...
# Processing Record 48 of Set 5 | remire-montjoly
# Processing Record 49 of Set 5 | nuuk
# Processing Record 0 of Set 6 | polyarnyy
# Processing Record 1 of Set 6 | pekan
# Processing Record 2 of Set 6 | la passe
# Processing Record 3 of Set 6 | fallon
# Processing Record 4 of Set 6 | karratha
# Processing Record 5 of Set 6 | kirakira
# Processing Record 6 of Set 6 | coquimatlan
# Processing Record 7 of Set 6 | melfi
# Processing Record 8 of Set 6 | abilene
# Processing Record 9 of Set 6 | linevo
# Processing Record 10 of Set 6 | gargalianoi
# Processing Record 11 of Set 6 | prince rupert
# Processing Record 12 of Set 6 | bossangoa
# Processing Record 13 of Set 6 | udachny
# Processing Record 14 of Set 6 | chernyshevskiy
# Processing Record 15 of Set 6 | nemuro
# Processing Record 16 of Set 6 | gilmer
# Processing Record 17 of Set 6 | boden
# Processing Record 18 of Set 6 | antonio enes
# Processing Record 19 of Set 6 | vila franca do campo
# Processing Record 20 of Set 6 | bima
# Processing Record 21 of Set 6 | geroskipou
# City not found. Skipping...
# Processing Record 22 of Set 6 | pangoa
# Processing Record 23 of Set 6 | kultali
# City not found. Skipping...
# Processing Record 24 of Set 6 | klaksvik
# Processing Record 25 of Set 6 | georgetown
# Processing Record 26 of Set 6 | charters towers
# Processing Record 27 of Set 6 | ketchikan
# Processing Record 28 of Set 6 | fort bragg
# Processing Record 29 of Set 6 | northam
# Processing Record 30 of Set 6 | puerto san jose
# Processing Record 31 of Set 6 | tazovsky
# Processing Record 32 of Set 6 | merritt
# Processing Record 33 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 34 of Set 6 | owen sound
# Processing Record 35 of Set 6 | nyala
# Processing Record 36 of Set 6 | portland
# Processing Record 37 of Set 6 | sisimiut
# Processing Record 38 of Set 6 | praia da vitoria
# Processing Record 39 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 40 of Set 6 | sosnogorsk
# Processing Record 41 of Set 6 | bom jesus
# Processing Record 42 of Set 6 | nizhniy kuranakh
# Processing Record 43 of Set 6 | freeport
# Processing Record 44 of Set 6 | xilin hot
# Processing Record 45 of Set 6 | pisco
# Processing Record 46 of Set 6 | vadso
# Processing Record 47 of Set 6 | carnarvon
# Processing Record 48 of Set 6 | vorkuta
# Processing Record 49 of Set 6 | cascais
# Processing Record 0 of Set 7 | sosnovo-ozerskoye
# Processing Record 1 of Set 7 | sydney
# Processing Record 2 of Set 7 | bontang
# Processing Record 3 of Set 7 | buedu
# Processing Record 4 of Set 7 | illizi
# Processing Record 5 of Set 7 | chibougamau
# Processing Record 6 of Set 7 | hailin
# Processing Record 7 of Set 7 | pir mahal
# Processing Record 8 of Set 7 | weining
# Processing Record 9 of Set 7 | akureyri
# Processing Record 10 of Set 7 | amlapura city
# City not found. Skipping...
# Processing Record 11 of Set 7 | mohr
# Processing Record 12 of Set 7 | walvis bay
# Processing Record 13 of Set 7 | pandan
# Processing Record 14 of Set 7 | yeonggwang
# Processing Record 15 of Set 7 | menongue
# Processing Record 16 of Set 7 | isola di capo rizzuto
# Processing Record 17 of Set 7 | sao jose da coroa grande
# Processing Record 18 of Set 7 | karad
# Processing Record 19 of Set 7 | yuzhno-kurilsk
# Processing Record 20 of Set 7 | skeldon
# Processing Record 21 of Set 7 | kone
# Processing Record 22 of Set 7 | east london
# Processing Record 23 of Set 7 | revda
# Processing Record 24 of Set 7 | huinca renanco
# Processing Record 25 of Set 7 | abaetetuba
# Processing Record 26 of Set 7 | kazanskoye
# Processing Record 27 of Set 7 | nazret
# Processing Record 28 of Set 7 | changli
# Processing Record 29 of Set 7 | saint croix
# Processing Record 30 of Set 7 | buraydah
# Processing Record 31 of Set 7 | ceres
# Processing Record 32 of Set 7 | cabedelo
# Processing Record 33 of Set 7 | tukrah
# Processing Record 34 of Set 7 | bikenibeu village
# Processing Record 35 of Set 7 | rio grande
# Processing Record 36 of Set 7 | timbuktu
# Processing Record 37 of Set 7 | krupki
# Processing Record 38 of Set 7 | butembo
# Processing Record 39 of Set 7 | zhezqazghan
# Processing Record 40 of Set 7 | labrador city
# Processing Record 41 of Set 7 | antsiranana
# Processing Record 42 of Set 7 | obidos
# Processing Record 43 of Set 7 | ivanteyevka
# Processing Record 44 of Set 7 | hermiston
# Processing Record 45 of Set 7 | vila do maio
# Processing Record 46 of Set 7 | pocatello
# Processing Record 47 of Set 7 | phan rang-thap cham
# Processing Record 48 of Set 7 | mejit
# Processing Record 49 of Set 7 | verkhnevilyuysk
# Processing Record 0 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 1 of Set 8 | naantali
# Processing Record 2 of Set 8 | saipan
# Processing Record 3 of Set 8 | sandnessjoen
# Processing Record 4 of Set 8 | floro
# Processing Record 5 of Set 8 | wewak
# Processing Record 6 of Set 8 | rongelap
# Processing Record 7 of Set 8 | zuwarah
# Processing Record 8 of Set 8 | korablino
# Processing Record 9 of Set 8 | maqat
# Processing Record 10 of Set 8 | huarmey
# Processing Record 11 of Set 8 | santa elena de uairen
# Processing Record 12 of Set 8 | surab
# Processing Record 13 of Set 8 | alice springs
# Processing Record 14 of Set 8 | saacow
# Processing Record 15 of Set 8 | khilok
# Processing Record 16 of Set 8 | dudinka
# Processing Record 17 of Set 8 | bengkulu
# Processing Record 18 of Set 8 | dakoro
# Processing Record 19 of Set 8 | cadale
# Processing Record 20 of Set 8 | howard springs
# Processing Record 21 of Set 8 | sonsorol village
# City not found. Skipping...
# Processing Record 22 of Set 8 | besisahar
# Processing Record 23 of Set 8 | okha
# Processing Record 24 of Set 8 | east ballina
# Processing Record 25 of Set 8 | cornwall
# Processing Record 26 of Set 8 | qarauyl
# Processing Record 27 of Set 8 | essaouira
# Processing Record 28 of Set 8 | kapuskasing
# Processing Record 29 of Set 8 | kamloops
# Processing Record 30 of Set 8 | turgen
# Processing Record 31 of Set 8 | bafra
# Processing Record 32 of Set 8 | fedorovka
# Processing Record 33 of Set 8 | kattivakkam
# Processing Record 34 of Set 8 | jidong
# Processing Record 35 of Set 8 | chokwe
# Processing Record 36 of Set 8 | pachino
# Processing Record 37 of Set 8 | mukah
# City not found. Skipping...
# Processing Record 38 of Set 8 | zaozersk
# Processing Record 39 of Set 8 | anqing
# Processing Record 40 of Set 8 | ocean city
# Processing Record 41 of Set 8 | port hueneme
# Processing Record 42 of Set 8 | selfoss
# Processing Record 43 of Set 8 | sinop
# Processing Record 44 of Set 8 | constitucion
# Processing Record 45 of Set 8 | kilju
# Processing Record 46 of Set 8 | utrik
# Processing Record 47 of Set 8 | lospalos
# Processing Record 48 of Set 8 | roma
# Processing Record 49 of Set 8 | shahpur
# Processing Record 0 of Set 9 | kupang
# Processing Record 1 of Set 9 | novokayakent
# Processing Record 2 of Set 9 | novi grad
# Processing Record 3 of Set 9 | indramayu
# Processing Record 4 of Set 9 | helena valley west central
# Processing Record 5 of Set 9 | pagar alam
# Processing Record 6 of Set 9 | chui
# Processing Record 7 of Set 9 | kralendijk
# Processing Record 8 of Set 9 | salina cruz
# Processing Record 9 of Set 9 | nantucket
# Processing Record 10 of Set 9 | kitangari
# Processing Record 11 of Set 9 | ar rutbah
# Processing Record 12 of Set 9 | la ronge
# Processing Record 13 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 9 | saint-paul
# Processing Record 15 of Set 9 | nanpara
# Processing Record 16 of Set 9 | laukaa
# Processing Record 17 of Set 9 | vorgashor
# Processing Record 18 of Set 9 | mata-utu
# Processing Record 19 of Set 9 | zaragoza
# Processing Record 20 of Set 9 | as sulayyil
# Processing Record 21 of Set 9 | suva
# Processing Record 22 of Set 9 | ciudad lazaro cardenas
# Processing Record 23 of Set 9 | youghal
# Processing Record 24 of Set 9 | khoyniki
# Processing Record 25 of Set 9 | parintins
# Processing Record 26 of Set 9 | el calafate
# Processing Record 27 of Set 9 | atafu village
# Processing Record 28 of Set 9 | martapura
# Processing Record 29 of Set 9 | alofi
# Processing Record 30 of Set 9 | port-vila
# Processing Record 31 of Set 9 | castillos
# Processing Record 32 of Set 9 | kapa'a
# Processing Record 33 of Set 9 | richards bay
# Processing Record 34 of Set 9 | keflavik
# Processing Record 35 of Set 9 | chamical
# Processing Record 36 of Set 9 | nova vicosa
# Processing Record 37 of Set 9 | valencia
# Processing Record 38 of Set 9 | homer
# Processing Record 39 of Set 9 | williams lake
# Processing Record 40 of Set 9 | oranjemund
# Processing Record 41 of Set 9 | talas
# Processing Record 42 of Set 9 | pacific grove
# Processing Record 43 of Set 9 | dubbo
# Processing Record 44 of Set 9 | kill devil hills
# Processing Record 45 of Set 9 | ta`u
# Processing Record 46 of Set 9 | motygino
# Processing Record 47 of Set 9 | suai
# City not found. Skipping...
# Processing Record 48 of Set 9 | kingston
# Processing Record 49 of Set 9 | san patricio
# Processing Record 0 of Set 10 | sinabang
# Processing Record 1 of Set 10 | dzhambeyty
# Processing Record 2 of Set 10 | nouadhibou
# Processing Record 3 of Set 10 | macapa
# Processing Record 4 of Set 10 | harrisburg
# Processing Record 5 of Set 10 | cockburn town
# Processing Record 6 of Set 10 | linden
# Processing Record 7 of Set 10 | labasa
# Processing Record 8 of Set 10 | jiangzi
# Processing Record 9 of Set 10 | lerwick
# Processing Record 10 of Set 10 | norfolk
# Processing Record 11 of Set 10 | thunder bay
# Processing Record 12 of Set 10 | yamada
# Processing Record 13 of Set 10 | amga
# Processing Record 14 of Set 10 | holualoa
# Processing Record 15 of Set 10 | wafangdian
# Processing Record 16 of Set 10 | smirnovo
# Processing Record 17 of Set 10 | iquitos
# Processing Record 18 of Set 10 | arraial do cabo
# Processing Record 19 of Set 10 | hun
# Processing Record 20 of Set 10 | ar ruways
# Processing Record 21 of Set 10 | masuda
# Processing Record 22 of Set 10 | jeddah
# Processing Record 23 of Set 10 | fortuna
# Processing Record 24 of Set 10 | arinos
# Processing Record 25 of Set 10 | richfield
# Processing Record 26 of Set 10 | pingnan
# Processing Record 27 of Set 10 | pula
# Processing Record 28 of Set 10 | clarkston heights-vineland
# Processing Record 29 of Set 10 | egersund
# Processing Record 30 of Set 10 | vernon
# Processing Record 31 of Set 10 | mesquite
# Processing Record 32 of Set 10 | lampasas
# Processing Record 33 of Set 10 | road town
# Processing Record 34 of Set 10 | port saint john's
# Processing Record 35 of Set 10 | xichang
# Processing Record 36 of Set 10 | nova xavantina
# Processing Record 37 of Set 10 | cambria
# Processing Record 38 of Set 10 | lorengau
# Processing Record 39 of Set 10 | camarinas
# Processing Record 40 of Set 10 | jurbarkas
# Processing Record 41 of Set 10 | elmendorf air force base
# City not found. Skipping...
# Processing Record 42 of Set 10 | novyy urengoy
# Processing Record 43 of Set 10 | buabidi
# City not found. Skipping...
# Processing Record 44 of Set 10 | zheshart
# Processing Record 45 of Set 10 | anatuya
# Processing Record 46 of Set 10 | tralee
# Processing Record 47 of Set 10 | andergrove
# Processing Record 48 of Set 10 | douz
# Processing Record 49 of Set 10 | papao
# Processing Record 0 of Set 11 | sao sepe
# Processing Record 1 of Set 11 | boa vista
# Processing Record 2 of Set 11 | valdivia
# Processing Record 3 of Set 11 | katsina-ala
# Processing Record 4 of Set 11 | kinarut
# Processing Record 5 of Set 11 | lazaro cardenas
# Processing Record 6 of Set 11 | troitsko-pechorsk
# Processing Record 7 of Set 11 | sanctuary point
# Processing Record 8 of Set 11 | ushtobe
# Processing Record 9 of Set 11 | santa terezinha
# Processing Record 10 of Set 11 | howrah
# Processing Record 11 of Set 11 | moshi
# Processing Record 12 of Set 11 | itambe
# Processing Record 13 of Set 11 | nyurba
# Processing Record 14 of Set 11 | round rock
# Processing Record 15 of Set 11 | rovaniemi
# Processing Record 16 of Set 11 | slave lake
# Processing Record 17 of Set 11 | palopo
# Processing Record 18 of Set 11 | touros
# Processing Record 19 of Set 11 | malango
# Processing Record 20 of Set 11 | el kala
# Processing Record 21 of Set 11 | mil'kovo
# Processing Record 22 of Set 11 | bahia de kino
# Processing Record 23 of Set 11 | katabu
# Processing Record 24 of Set 11 | zhangatas
# Processing Record 25 of Set 11 | villa yapacani
# Processing Record 26 of Set 11 | struer
# Processing Record 27 of Set 11 | ranot
# Processing Record 28 of Set 11 | murghob
# Processing Record 29 of Set 11 | khanty-mansiysk
# Processing Record 30 of Set 11 | zhangzhou
# Processing Record 31 of Set 11 | akjoujt
# Processing Record 32 of Set 11 | queenstown
# Processing Record 33 of Set 11 | bourbon-lancy
# Processing Record 34 of Set 11 | north platte
# Processing Record 35 of Set 11 | corning
# Processing Record 36 of Set 11 | arvayheer
# Processing Record 37 of Set 11 | dalandzadgad
# Processing Record 38 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 39 of Set 11 | bowen
# Processing Record 40 of Set 11 | along
# Processing Record 41 of Set 11 | ulladulla
# Processing Record 42 of Set 11 | monroe
# Processing Record 43 of Set 11 | elverum
# Processing Record 44 of Set 11 | lagodekhi
# Processing Record 45 of Set 11 | puerto baquerizo moreno
# Processing Record 46 of Set 11 | gijang
# Processing Record 47 of Set 11 | amungan
# Processing Record 48 of Set 11 | chos malal
# Processing Record 49 of Set 11 | wuhai
# Processing Record 0 of Set 12 | adigrat
# Processing Record 1 of Set 12 | san rafael
# Processing Record 2 of Set 12 | al hufuf
# Processing Record 3 of Set 12 | prince george
# Processing Record 4 of Set 12 | olyokminsk
# Processing Record 5 of Set 12 | imperatriz
# Processing Record 6 of Set 12 | comodoro rivadavia
# Processing Record 7 of Set 12 | ishigaki
# Processing Record 8 of Set 12 | canmore
# Processing Record 9 of Set 12 | mahina
# Processing Record 10 of Set 12 | bandipura
# Processing Record 11 of Set 12 | bhanpura
# Processing Record 12 of Set 12 | pangai
# Processing Record 13 of Set 12 | tindouf
# Processing Record 14 of Set 12 | usinsk
# Processing Record 15 of Set 12 | mili
# Processing Record 16 of Set 12 | katsuura
# Processing Record 17 of Set 12 | deshnoke
# Processing Record 18 of Set 12 | cam ranh
# Processing Record 19 of Set 12 | borgarnes
# Processing Record 20 of Set 12 | korla
# Processing Record 21 of Set 12 | dunedin
# Processing Record 22 of Set 12 | kuching
# Processing Record 23 of Set 12 | solvang
# Processing Record 24 of Set 12 | vila velha
# Processing Record 25 of Set 12 | namibe
# Processing Record 26 of Set 12 | kulachi
# Processing Record 27 of Set 12 | tadine
# Processing Record 28 of Set 12 | onega
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'adamstown',
#   'Lat': -25.066,
#   'Lng': -130.1015,
#   'Max Temp': 22.82,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 6.68,
#   'Country': 'PN',
#   'Date': 1702960281},
#  {'City': 'puerto natales',
#   'Lat': -51.7236,
#   'Lng': -72.4875,
#   'Max Temp': 8.45,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 1.83,
#   'Country': 'CL',
#   'Date': 1702960552},
#  {'City': 'la mira',
#   'Lat': 18.035,
#   'Lng': -102.3266,
#   'Max Temp': 23.73,
#   'Humidity': 89,
#   'Cloudiness': 7,
#   'Wind Speed': 1.69,
#   'Country': 'MX',
#   'Date': 1702960553},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 6.4,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1702960417},
#  {'City': 'port-aux-francais',
#   'Lat': -49.35,
#   'Lng': 70.2167,
#   'Max Temp': 6.1,
#   'Humidity': 74,
#   'Cloudiness': 56,
#   'Wind Speed': 12.09,
#   'Country': 'TF',
#   'Date': 1702960523},
#  {'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 17.1,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 2.4,
#   'Country': 'ZA',
#   'Date': 1702960553},
#  {'City': 'stanley',
#   'Lat': 54.868,
#   'Lng': -1.6985,
#   'Max Temp': 8.49,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'GB',
#   'Date': 1702960553},
#  {'City': 'isafjordur',
#   'Lat': 66.0755,
#   'Lng': -23.124,
#   'Max Temp': -2.78,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 2.72,
#   'Country': 'IS',
#   'Date': 1702960553},
#  {'City': 'hawaiian paradise park',
#   'Lat': 19.5933,
#   'Lng': -154.9731,
#   'Max Temp': 21.73,
#   'Humidity': 92,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1702960553},
#  {'City': 'wonsan',
#   'Lat': 39.1528,
#   'Lng': 127.4436,
#   'Max Temp': -2.36,
#   'Humidity': 66,
#   'Cloudiness': 70,
#   'Wind Speed': 0.59,
#   'Country': 'KP',
#   'Date': 1702960553},
#  {'City': 'cromer',
#   'Lat': 52.9312,
#   'Lng': 1.2989,
#   'Max Temp': 12.26,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.9,
#   'Country': 'GB',
#   'Date': 1702960553},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': -19.72,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 3,
#   'Country': 'RU',
#   'Date': 1702960553},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 24.75,
#   'Humidity': 95,
#   'Cloudiness': 47,
#   'Wind Speed': 0.89,
#   'Country': 'EC',
#   'Date': 1702960286},
#  {'City': 'chinde',
#   'Lat': 26.8418,
#   'Lng': 88.0763,
#   'Max Temp': 15.93,
#   'Humidity': 49,
#   'Cloudiness': 12,
#   'Wind Speed': 2.51,
#   'Country': 'NP',
#   'Date': 1702960553},
#  {'City': 'klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': -10.55,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 8.91,
#   'Country': 'RU',
#   'Date': 1702960553},
#  {'City': 'afaahiti',
#   'Lat': -17.75,
#   'Lng': -149.2833,
#   'Max Temp': 25.93,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.71,
#   'Country': 'PF',
#   'Date': 1702960554},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -17.62,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 6.04,
#   'Country': 'RU',
#   'Date': 1702960554},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 11.81,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 7.2,
#   'Country': 'AR',
#   'Date': 1702960554},
#  {'City': 'hadibu',
#   'Lat': 12.65,
#   'Lng': 54.0333,
#   'Max Temp': 25.04,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 6.47,
#   'Country': 'YE',
#   'Date': 1702960554},
#  {'City': 'quinhamel',
#   'Lat': 11.8833,
#   'Lng': -15.85,
#   'Max Temp': 23.73,
#   'Humidity': 25,
#   'Cloudiness': 100,
#   'Wind Speed': 5.06,
#   'Country': 'GW',
#   'Date': 1702960554},
#  {'City': 'waitangi',
#   'Lat': -43.9535,
#   'Lng': -176.5597,
#   'Max Temp': 16.57,
#   'Humidity': 70,
#   'Cloudiness': 38,
#   'Wind Speed': 2.98,
#   'Country': 'NZ',
#   'Date': 1702960554},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 17.42,
#   'Humidity': 66,
#   'Cloudiness': 49,
#   'Wind Speed': 7.23,
#   'Country': 'NA',
#   'Date': 1702960554},
#  {'City': 'corowa',
#   'Lat': -36.0333,
#   'Lng': 146.3833,
#   'Max Temp': 28.65,
#   'Humidity': 44,
#   'Cloudiness': 84,
#   'Wind Speed': 7.44,
#   'Country': 'AU',
#   'Date': 1702960554},
#  {'City': 'geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 39.23,
#   'Humidity': 15,
#   'Cloudiness': 6,
#   'Wind Speed': 3.6,
#   'Country': 'AU',
#   'Date': 1702960554},
#  {'City': 'port mathurin',
#   'Lat': -19.6833,
#   'Lng': 63.4167,
#   'Max Temp': 26.88,
#   'Humidity': 81,
#   'Cloudiness': 28,
#   'Wind Speed': 7.93,
#   'Country': 'MU',
#   'Date': 1702960554},
#  {'City': 'edinburgh of the seven seas',
#   'Lat': -37.0676,
#   'Lng': -12.3116,
#   'Max Temp': 15.1,
#   'Humidity': 82,
#   'Cloudiness': 57,
#   'Wind Speed': 8.96,
#   'Country': 'SH',
#   'Date': 1702960554},
#  {'City': 'las toscas',
#   'Lat': -28.3529,
#   'Lng': -59.258,
#   'Max Temp': 22.52,
#   'Humidity': 96,
#   'Cloudiness': 98,
#   'Wind Speed': 2.8,
#   'Country': 'AR',
#   'Date': 1702960555},
#  {'City': 'trelissac',
#   'Lat': 45.1977,
#   'Lng': 0.7862,
#   'Max Temp': 1.71,
#   'Humidity': 92,
#   'Cloudiness': 4,
#   'Wind Speed': 0.63,
#   'Country': 'FR',
#   'Date': 1702960555},
#  {'City': 'grytviken',
#   'Lat': -54.2811,
#   'Lng': -36.5092,
#   'Max Temp': 2.36,
#   'Humidity': 66,
#   'Cloudiness': 17,
#   'Wind Speed': 3.1,
#   'Country': 'GS',
#   'Date': 1702960555},
#  {'City': 'kailua-kona',
#   'Lat': 19.6406,
#   'Lng': -155.9956,
#   'Max Temp': 22.98,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1702960555},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 10.06,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'CL',
#   'Date': 1702960555},
#  {'City': 'novodvinsk',
#   'Lat': 64.4165,
#   'Lng': 40.8122,
#   'Max Temp': -3.14,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 1.91,
#   'Country': 'RU',
#   'Date': 1702960555},
#  {'City': 'saint-philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 29.77,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 1.81,
#   'Country': 'RE',
#   'Date': 1702960555},
#  {'City': 'yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 30.88,
#   'Humidity': 63,
#   'Cloudiness': 7,
#   'Wind Speed': 5.47,
#   'Country': 'AU',
#   'Date': 1702960555},
#  {'City': 'happy valley-goose bay',
#   'Lat': 53.3168,
#   'Lng': -60.3315,
#   'Max Temp': 9.17,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'CA',
#   'Date': 1702960555},
#  {'City': 'santana',
#   'Lat': -0.0583,
#   'Lng': -51.1817,
#   'Max Temp': 27.1,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'BR',
#   'Date': 1702960555},
#  {'City': 'broken hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 29.26,
#   'Humidity': 28,
#   'Cloudiness': 49,
#   'Wind Speed': 10.16,
#   'Country': 'AU',
#   'Date': 1702960555},
#  {'City': 'qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': -4.31,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 4.62,
#   'Country': 'GL',
#   'Date': 1702960556},
#  {'City': 'jamaame',
#   'Lat': 0.0697,
#   'Lng': 42.745,
#   'Max Temp': 28.59,
#   'Humidity': 69,
#   'Cloudiness': 96,
#   'Wind Speed': 5.82,
#   'Country': 'SO',
#   'Date': 1702960556},
#  {'City': 'coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 15.85,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 1.03,
#   'Country': 'CL',
#   'Date': 1702960306},
#  {'City': 'lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 3.66,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 1.34,
#   'Country': 'PT',
#   'Date': 1702960556},
#  {'City': 'kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 28.72,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 2.74,
#   'Country': 'PG',
#   'Date': 1702960556},
#  {'City': 'oamaru',
#   'Lat': -45.0784,
#   'Lng': 170.9801,
#   'Max Temp': 19.1,
#   'Humidity': 72,
#   'Cloudiness': 83,
#   'Wind Speed': 5.52,
#   'Country': 'NZ',
#   'Date': 1702960380},
#  {'City': 'saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 12.03,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 6.1,
#   'Country': 'ZA',
#   'Date': 1702960556},
#  {'City': 'new norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 16.72,
#   'Humidity': 52,
#   'Cloudiness': 68,
#   'Wind Speed': 2.09,
#   'Country': 'AU',
#   'Date': 1702960556},
#  {'City': 'invercargill',
#   'Lat': -46.4,
#   'Lng': 168.35,
#   'Max Temp': 19.06,
#   'Humidity': 47,
#   'Cloudiness': 93,
#   'Wind Speed': 3.05,
#   'Country': 'NZ',
#   'Date': 1702960505},
#  {'City': 'bonthe',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 22.78,
#   'Humidity': 70,
#   'Cloudiness': 79,
#   'Wind Speed': 2.28,
#   'Country': 'SL',
#   'Date': 1702960556},
#  {'City': 'bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -32.23,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.59,
#   'Country': 'RU',
#   'Date': 1702960556},
#  {'City': 'port lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 17.27,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 8.69,
#   'Country': 'AU',
#   'Date': 1702960556},
#  {'City': 'ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 10.28,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 2.71,
#   'Country': 'CL',
#   'Date': 1702960556},
#  {'City': 'petropavlovsk-kamchatsky',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': -4.67,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 4.02,
#   'Country': 'RU',
#   'Date': 1702960557},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 4.94,
#   'Humidity': 80,
#   'Cloudiness': 60,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Date': 1702960557},
#  {'City': "ust'-kulom",
#   'Lat': 61.6864,
#   'Lng': 53.6902,
#   'Max Temp': -5.02,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 2.98,
#   'Country': 'RU',
#   'Date': 1702960557},
#  {'City': 'tamanrasset',
#   'Lat': 22.785,
#   'Lng': 5.5228,
#   'Max Temp': -1.05,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'DZ',
#   'Date': 1702960557},
#  {'City': 'blackmans bay',
#   'Lat': -43.0167,
#   'Lng': 147.3167,
#   'Max Temp': 16.07,
#   'Humidity': 63,
#   'Cloudiness': 84,
#   'Wind Speed': 5.22,
#   'Country': 'AU',
#   'Date': 1702960557},
#  {'City': 'reggane',
#   'Lat': 26.7158,
#   'Lng': 0.1714,
#   'Max Temp': 8.14,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 3.72,
#   'Country': 'DZ',
#   'Date': 1702960557},
#  {'City': 'tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 23.18,
#   'Humidity': 50,
#   'Cloudiness': 18,
#   'Wind Speed': 0.18,
#   'Country': 'IN',
#   'Date': 1702960557},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -29.42,
#   'Humidity': 85,
#   'Cloudiness': 7,
#   'Wind Speed': 2.93,
#   'Country': 'CA',
#   'Date': 1702960557},
#  {'City': 'sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 23.23,
#   'Humidity': 56,
#   'Cloudiness': 15,
#   'Wind Speed': 2.56,
#   'Country': 'OM',
#   'Date': 1702960557},
#  {'City': 'mammoth lakes',
#   'Lat': 37.6485,
#   'Lng': -118.9721,
#   'Max Temp': 4.63,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1702960557},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 1.77,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75,
#   'Country': 'US',
#   'Date': 1702960557},
#  {'City': 'whitehorse',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': -12.88,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 1.03,
#   'Country': 'CA',
#   'Date': 1702960557},
#  {'City': 'tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 28.45,
#   'Humidity': 80,
#   'Cloudiness': 58,
#   'Wind Speed': 7.71,
#   'Country': 'ID',
#   'Date': 1702960558},
#  {'City': 'haiku-pauwela',
#   'Lat': 20.9219,
#   'Lng': -156.3051,
#   'Max Temp': 22.8,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 7.72,
#   'Country': 'US',
#   'Date': 1702960558},
#  {'City': 'minas de marcona',
#   'Lat': -15.2119,
#   'Lng': -75.1103,
#   'Max Temp': 15.52,
#   'Humidity': 91,
#   'Cloudiness': 70,
#   'Wind Speed': 4.88,
#   'Country': 'PE',
#   'Date': 1702960558},
#  {'City': 'uturoa',
#   'Lat': -16.7333,
#   'Lng': -151.4333,
#   'Max Temp': 26.54,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 3.6,
#   'Country': 'PF',
#   'Date': 1702960558},
#  {'City': 'isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 27.06,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'VU',
#   'Date': 1702960558},
#  {'City': 'samitah',
#   'Lat': 16.596,
#   'Lng': 42.9444,
#   'Max Temp': 24.39,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 0.93,
#   'Country': 'SA',
#   'Date': 1702960558},
#  {'City': 'anzio',
#   'Lat': 41.4853,
#   'Lng': 12.6179,
#   'Max Temp': 9.52,
#   'Humidity': 52,
#   'Cloudiness': 3,
#   'Wind Speed': 3,
#   'Country': 'IT',
#   'Date': 1702960558},
#  {'City': 'weno',
#   'Lat': 7.4515,
#   'Lng': 151.8468,
#   'Max Temp': 30.97,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 5.66,
#   'Country': 'FM',
#   'Date': 1702960558},
#  {'City': 'quellon',
#   'Lat': -43.1167,
#   'Lng': -73.6167,
#   'Max Temp': 9.66,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 4.98,
#   'Country': 'CL',
#   'Date': 1702960558},
#  {'City': 'alibag',
#   'Lat': 18.6411,
#   'Lng': 72.8792,
#   'Max Temp': 27.04,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 3.57,
#   'Country': 'IN',
#   'Date': 1702960558},
#  {'City': 'tulun',
#   'Lat': 54.5611,
#   'Lng': 100.5792,
#   'Max Temp': -25.27,
#   'Humidity': 94,
#   'Cloudiness': 67,
#   'Wind Speed': 0.94,
#   'Country': 'RU',
#   'Date': 1702960558},
#  {'City': 'santa marta de ortigueira',
#   'Lat': 43.6833,
#   'Lng': -7.85,
#   'Max Temp': 8.01,
#   'Humidity': 78,
#   'Cloudiness': 11,
#   'Wind Speed': 3.35,
#   'Country': 'ES',
#   'Date': 1702960558},
#  {'City': 'badiyah',
#   'Lat': 22.45,
#   'Lng': 58.8,
#   'Max Temp': 20.33,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 0.61,
#   'Country': 'OM',
#   'Date': 1702960558},
#  {'City': 'batman',
#   'Lat': 37.8874,
#   'Lng': 41.1322,
#   'Max Temp': -1.11,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 0.51,
#   'Country': 'TR',
#   'Date': 1702960559},
#  {'City': 'margaret river',
#   'Lat': -33.95,
#   'Lng': 115.0667,
#   'Max Temp': 26.03,
#   'Humidity': 38,
#   'Cloudiness': 4,
#   'Wind Speed': 3.7,
#   'Country': 'AU',
#   'Date': 1702960559},
#  {'City': 'port elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 19.62,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'ZA',
#   'Date': 1702960559},
#  {'City': 'inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 26.99,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 2.06,
#   'Country': 'MZ',
#   'Date': 1702960559},
#  {'City': 'ishikawa',
#   'Lat': 26.4233,
#   'Lng': 127.8214,
#   'Max Temp': 25.18,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Country': 'JP',
#   'Date': 1702960559},
#  {'City': 'collie',
#   'Lat': -33.3667,
#   'Lng': 116.15,
#   'Max Temp': 30.11,
#   'Humidity': 21,
#   'Cloudiness': 3,
#   'Wind Speed': 3.92,
#   'Country': 'AU',
#   'Date': 1702960559},
#  {'City': 'hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 8.22,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.64,
#   'Country': 'JP',
#   'Date': 1702960559},
#  {'City': 'gejiu',
#   'Lat': 23.306,
#   'Lng': 103.1635,
#   'Max Temp': 12.66,
#   'Humidity': 68,
#   'Cloudiness': 82,
#   'Wind Speed': 2.76,
#   'Country': 'CN',
#   'Date': 1702960559},
#  {'City': 'san antonio de pale',
#   'Lat': -1.4014,
#   'Lng': 5.6325,
#   'Max Temp': 27.33,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 3.08,
#   'Country': 'GQ',
#   'Date': 1702960559},
#  {'City': 'sesheke',
#   'Lat': -17.4759,
#   'Lng': 24.2968,
#   'Max Temp': 21.37,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 0.65,
#   'Country': 'ZM',
#   'Date': 1702960559},
#  {'City': 'le trait',
#   'Lat': 49.4689,
#   'Lng': 0.8163,
#   'Max Temp': 7.75,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 4.73,
#   'Country': 'FR',
#   'Date': 1702960559},
#  {'City': 'sisak',
#   'Lat': 45.4661,
#   'Lng': 16.3783,
#   'Max Temp': -4.01,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 0.49,
#   'Country': 'HR',
#   'Date': 1702960559},
#  {'City': 'qamdo',
#   'Lat': 31.1667,
#   'Lng': 97.2333,
#   'Max Temp': -2.35,
#   'Humidity': 24,
#   'Cloudiness': 3,
#   'Wind Speed': 3.07,
#   'Country': 'CN',
#   'Date': 1702960559},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 27.66,
#   'Humidity': 77,
#   'Cloudiness': 42,
#   'Wind Speed': 2.81,
#   'Country': 'MV',
#   'Date': 1702960560},
#  {'City': 'ngaoundere',
#   'Lat': 7.3167,
#   'Lng': 13.5833,
#   'Max Temp': 18.5,
#   'Humidity': 29,
#   'Cloudiness': 99,
#   'Wind Speed': 1.75,
#   'Country': 'CM',
#   'Date': 1702960560},
#  {'City': 'kerikeri',
#   'Lat': -35.2268,
#   'Lng': 173.9474,
#   'Max Temp': 21.04,
#   'Humidity': 71,
#   'Cloudiness': 44,
#   'Wind Speed': 2.5,
#   'Country': 'NZ',
#   'Date': 1702960560},
#  {'City': 'nova mayachka',
#   'Lat': 46.6,
#   'Lng': 33.2271,
#   'Max Temp': 5.92,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Country': 'UA',
#   'Date': 1702960560},
#  {'City': 'bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 26.56,
#   'Humidity': 42,
#   'Cloudiness': 94,
#   'Wind Speed': 8.97,
#   'Country': 'GW',
#   'Date': 1702960560},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 15.45,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 4.14,
#   'Country': 'ZA',
#   'Date': 1702960560},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 26.03,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'CK',
#   'Date': 1702960533},
#  {'City': "st. john's",
#   'Lat': 47.5649,
#   'Lng': -52.7093,
#   'Max Temp': 9.32,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 9.77,
#   'Country': 'CA',
#   'Date': 1702960387},
#  {'City': 'jackson',
#   'Lat': 42.4165,
#   'Lng': -122.8345,
#   'Max Temp': 10.21,
#   'Humidity': 81,
#   'Cloudiness': 84,
#   'Wind Speed': 1.97,
#   'Country': 'US',
#   'Date': 1702960399},
#  {'City': 'kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 40.99,
#   'Humidity': 37,
#   'Cloudiness': 52,
#   'Wind Speed': 3.6,
#   'Country': 'AU',
#   'Date': 1702960286},
#  {'City': 'ojinaga',
#   'Lat': 29.5667,
#   'Lng': -104.4167,
#   'Max Temp': 15.53,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'MX',
#   'Date': 1702960560},
#  {'City': 'opuwo',
#   'Lat': -18.0607,
#   'Lng': 13.84,
#   'Max Temp': 24.07,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'NA',
#   'Date': 1702960560},
#  {'City': 'ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': -9.99,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'GL',
#   'Date': 1702960560},
#  {'City': 'necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 11.27,
#   'Humidity': 64,
#   'Cloudiness': 2,
#   'Wind Speed': 5.1,
#   'Country': 'AR',
#   'Date': 1702960560},
#  {'City': 'mariakani',
#   'Lat': -3.8633,
#   'Lng': 39.4736,
#   'Max Temp': 24.05,
#   'Humidity': 79,
#   'Cloudiness': 39,
#   'Wind Speed': 1.51,
#   'Country': 'KE',
#   'Date': 1702960561},
#  {'City': 'nova sintra',
#   'Lat': 14.8667,
#   'Lng': -24.7167,
#   'Max Temp': 21.14,
#   'Humidity': 69,
#   'Cloudiness': 13,
#   'Wind Speed': 5.41,
#   'Country': 'CV',
#   'Date': 1702960561},
#  {'City': 'kzyltu',
#   'Lat': 53.6364,
#   'Lng': 72.3414,
#   'Max Temp': -4.03,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.88,
#   'Country': 'KZ',
#   'Date': 1702960561},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 13.76,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 12.07,
#   'Country': 'PT',
#   'Date': 1702960561},
#  {'City': 'shanhecun',
#   'Lat': 44.7,
#   'Lng': 127.2,
#   'Max Temp': -17.36,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Country': 'CN',
#   'Date': 1702960374},
#  {'City': 'senillosa',
#   'Lat': -39,
#   'Lng': -68.4167,
#   'Max Temp': 16.88,
#   'Humidity': 31,
#   'Cloudiness': 33,
#   'Wind Speed': 9.33,
#   'Country': 'AR',
#   'Date': 1702960561},
#  {'City': 'whakatane',
#   'Lat': -37.9585,
#   'Lng': 176.9854,
#   'Max Temp': 24.38,
#   'Humidity': 75,
#   'Cloudiness': 51,
#   'Wind Speed': 2.78,
#   'Country': 'NZ',
#   'Date': 1702960561},
#  {'City': 'sault ste. marie',
#   'Lat': 46.5168,
#   'Lng': -84.3333,
#   'Max Temp': -6.69,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 6.17,
#   'Country': 'CA',
#   'Date': 1702960292},
#  {'City': 'mount isa',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 37.87,
#   'Humidity': 30,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'AU',
#   'Date': 1702960561},
#  {'City': 'sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 1.94,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1702960561},
#  {'City': 'port alberni',
#   'Lat': 49.2413,
#   'Lng': -124.8028,
#   'Max Temp': 7.91,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Country': 'CA',
#   'Date': 1702960562},
#  {'City': 'west island',
#   'Lat': -12.1568,
#   'Lng': 96.8225,
#   'Max Temp': 29.99,
#   'Humidity': 62,
#   'Cloudiness': 15,
#   'Wind Speed': 4.12,
#   'Country': 'CC',
#   'Date': 1702960562},
#  {'City': 'byford',
#   'Lat': -32.2167,
#   'Lng': 116,
#   'Max Temp': 31.49,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 9.77,
#   'Country': 'AU',
#   'Date': 1702960562},
#  {'City': 'chonchi',
#   'Lat': -42.6128,
#   'Lng': -73.8092,
#   'Max Temp': 10.56,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.51,
#   'Country': 'CL',
#   'Date': 1702960562},
#  {'City': 'port blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 31.02,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Country': 'IN',
#   'Date': 1702960562},
#  {'City': 'yelizovo',
#   'Lat': 53.1873,
#   'Lng': 158.3805,
#   'Max Temp': -3.92,
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 3,
#   'Country': 'RU',
#   'Date': 1702960562},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -26.36,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'CA',
#   'Date': 1702960563},
#  {'City': 'ikedacho',
#   'Lat': 34.0167,
#   'Lng': 133.8,
#   'Max Temp': 3.24,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 1.73,
#   'Country': 'JP',
#   'Date': 1702960563},
#  {'City': 'aasiaat',
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': -11.9,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 8.36,
#   'Country': 'GL',
#   'Date': 1702960563},
#  {'City': 'prado',
#   'Lat': -17.3411,
#   'Lng': -39.2208,
#   'Max Temp': 23.81,
#   'Humidity': 92,
#   'Cloudiness': 69,
#   'Wind Speed': 3.16,
#   'Country': 'BR',
#   'Date': 1702960563},
#  {'City': 'maamba',
#   'Lat': -17.3667,
#   'Lng': 27.15,
#   'Max Temp': 22.74,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.09,
#   'Country': 'ZM',
#   'Date': 1702960563},
#  {'City': 'pamandzi',
#   'Lat': -12.7967,
#   'Lng': 45.2794,
#   'Max Temp': 27.88,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'YT',
#   'Date': 1702960563},
#  {'City': 'mar del plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 13.38,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 7.15,
#   'Country': 'AR',
#   'Date': 1702960384},
#  {'City': 'kasese',
#   'Lat': 0.1833,
#   'Lng': 30.0833,
#   'Max Temp': 22.22,
#   'Humidity': 76,
#   'Cloudiness': 46,
#   'Wind Speed': 0.73,
#   'Country': 'UG',
#   'Date': 1702960563},
#  {'City': 'cill airne',
#   'Lat': 52.05,
#   'Lng': -9.5167,
#   'Max Temp': 8.83,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Country': 'IE',
#   'Date': 1702960564},
#  {'City': 'lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 17.1,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1702960285},
#  {'City': 'constantia',
#   'Lat': 44.1833,
#   'Lng': 28.65,
#   'Max Temp': 2.61,
#   'Humidity': 71,
#   'Cloudiness': 8,
#   'Wind Speed': 3.03,
#   'Country': 'RO',
#   'Date': 1702960564},
#  {'City': 'mount pearl',
#   'Lat': 47.5166,
#   'Lng': -52.7813,
#   'Max Temp': 8.86,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 9.77,
#   'Country': 'CA',
#   'Date': 1702960564},
#  {'City': 'wanzleben',
#   'Lat': 52.05,
#   'Lng': 11.45,
#   'Max Temp': 10.32,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.18,
#   'Country': 'DE',
#   'Date': 1702960564},
#  {'City': 'lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 11.26,
#   'Humidity': 90,
#   'Cloudiness': 6,
#   'Wind Speed': 6.08,
#   'Country': 'CL',
#   'Date': 1702960564},
#  {'City': 'susuman',
#   'Lat': 62.7833,
#   'Lng': 148.1667,
#   'Max Temp': -36.4,
#   'Humidity': 100,
#   'Cloudiness': 97,
#   'Wind Speed': 0.42,
#   'Country': 'RU',
#   'Date': 1702960564},
#  {'City': 'christchurch',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 19.67,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Country': 'NZ',
#   'Date': 1702960507},
#  {'City': 'anloga',
#   'Lat': 5.7947,
#   'Lng': 0.8973,
#   'Max Temp': 27.09,
#   'Humidity': 82,
#   'Cloudiness': 89,
#   'Wind Speed': 3.76,
#   'Country': 'GH',
#   'Date': 1702960564},
#  {'City': 'ola',
#   'Lat': 59.5833,
#   'Lng': 151.2833,
#   'Max Temp': -23.66,
#   'Humidity': 84,
#   'Cloudiness': 41,
#   'Wind Speed': 5.27,
#   'Country': 'RU',
#   'Date': 1702960564},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': -4.27,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1702960564},
#  {'City': 'ilanskiy',
#   'Lat': 56.2358,
#   'Lng': 96.065,
#   'Max Temp': -25.87,
#   'Humidity': 94,
#   'Cloudiness': 10,
#   'Wind Speed': 2.07,
#   'Country': 'RU',
#   'Date': 1702960564},
#  {'City': 'olonkinbyen',
#   'Lat': 70.9221,
#   'Lng': -8.7187,
#   'Max Temp': -3.61,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'SJ',
#   'Date': 1702960564},
#  {'City': 'mount gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 17.27,
#   'Humidity': 45,
#   'Cloudiness': 4,
#   'Wind Speed': 5.69,
#   'Country': 'AU',
#   'Date': 1702960565},
#  {'City': 'muisne',
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp': 24.99,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Country': 'EC',
#   'Date': 1702960565},
#  {'City': 'fort st. john',
#   'Lat': 56.2499,
#   'Lng': -120.8529,
#   'Max Temp': -6.06,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'CA',
#   'Date': 1702960521},
#  {'City': 'codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 16.58,
#   'Humidity': 49,
#   'Cloudiness': 10,
#   'Wind Speed': 7.45,
#   'Country': 'AU',
#   'Date': 1702960565},
#  {'City': 'popondetta',
#   'Lat': -8.7537,
#   'Lng': 148.2534,
#   'Max Temp': 28.15,
#   'Humidity': 80,
#   'Cloudiness': 93,
#   'Wind Speed': 1.74,
#   'Country': 'PG',
#   'Date': 1702960565},
#  {'City': 'hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': -1.57,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 5.81,
#   'Country': 'US',
#   'Date': 1702960565},
#  {'City': 'palu',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 31.51,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Country': 'ID',
#   'Date': 1702960565},
#  {'City': 'wenchang',
#   'Lat': 30.904,
#   'Lng': 118.4887,
#   'Max Temp': 1.08,
#   'Humidity': 96,
#   'Cloudiness': 98,
#   'Wind Speed': 1.87,
#   'Country': 'CN',
#   'Date': 1702960565},
#  {'City': 'lugazi',
#   'Lat': 0.3772,
#   'Lng': 32.9197,
#   'Max Temp': 19.7,
#   'Humidity': 90,
#   'Cloudiness': 91,
#   'Wind Speed': 0.6,
#   'Country': 'UG',
#   'Date': 1702960565},
#  {'City': 'jalai nur',
#   'Lat': 49.45,
#   'Lng': 117.7,
#   'Max Temp': -26.84,
#   'Humidity': 83,
#   'Cloudiness': 77,
#   'Wind Speed': 1,
#   'Country': 'CN',
#   'Date': 1702960565},
#  {'City': 'buka',
#   'Lat': 40.8108,
#   'Lng': 69.1986,
#   'Max Temp': 3.72,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Country': 'UZ',
#   'Date': 1702960566},
#  {'City': 'yallahs',
#   'Lat': 17.8748,
#   'Lng': -76.5624,
#   'Max Temp': 26.85,
#   'Humidity': 85,
#   'Cloudiness': 89,
#   'Wind Speed': 2.2,
#   'Country': 'JM',
#   'Date': 1702960566},
#  {'City': 'macia',
#   'Lat': -25.0269,
#   'Lng': 33.0989,
#   'Max Temp': 25.33,
#   'Humidity': 87,
#   'Cloudiness': 53,
#   'Wind Speed': 2.87,
#   'Country': 'MZ',
#   'Date': 1702960566},
#  {'City': 'egilsstadir',
#   'Lat': 65.2653,
#   'Lng': -14.3948,
#   'Max Temp': -7.05,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 1.54,
#   'Country': 'IS',
#   'Date': 1702960566},
#  {'City': 'manokwari',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 27.78,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.41,
#   'Country': 'ID',
#   'Date': 1702960566},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -13.77,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 8.14,
#   'Country': 'RU',
#   'Date': 1702960566},
#  {'City': 'ghadamis',
#   'Lat': 30.1337,
#   'Lng': 9.5007,
#   'Max Temp': 9.81,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 0.81,
#   'Country': 'LY',
#   'Date': 1702960566},
#  {'City': 'laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 14.49,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1702960566},
#  {'City': 'college',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -11.97,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1702960566},
#  {'City': 'longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': -5.09,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 7.72,
#   'Country': 'SJ',
#   'Date': 1702960513},
#  {'City': 'gadzhiyevo',
#   'Lat': 69.2551,
#   'Lng': 33.3362,
#   'Max Temp': -11.64,
#   'Humidity': 90,
#   'Cloudiness': 11,
#   'Wind Speed': 4.94,
#   'Country': 'RU',
#   'Date': 1702960396},
#  {'City': 'yeed',
#   'Lat': 4.55,
#   'Lng': 43.0333,
#   'Max Temp': 25.68,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 8.37,
#   'Country': 'SO',
#   'Date': 1702960567},
#  {'City': 'melchor de mencos',
#   'Lat': 17.0686,
#   'Lng': -89.1522,
#   'Max Temp': 16,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'GT',
#   'Date': 1702960567},
#  {'City': 'fort stockton',
#   'Lat': 30.894,
#   'Lng': -102.8793,
#   'Max Temp': 12.64,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1702960567},
#  {'City': 'calvinia',
#   'Lat': -31.4707,
#   'Lng': 19.776,
#   'Max Temp': 16.9,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'ZA',
#   'Date': 1702960567},
#  {'City': 'rabaul',
#   'Lat': -4.1967,
#   'Lng': 152.1721,
#   'Max Temp': 26.26,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.39,
#   'Country': 'PG',
#   'Date': 1702960567},
#  {'City': 'dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 23.93,
#   'Humidity': 46,
#   'Cloudiness': 73,
#   'Wind Speed': 9.93,
#   'Country': 'IN',
#   'Date': 1702960567},
#  {'City': 'chilecito',
#   'Lat': -29.1619,
#   'Lng': -67.4974,
#   'Max Temp': 16.66,
#   'Humidity': 62,
#   'Cloudiness': 23,
#   'Wind Speed': 5.48,
#   'Country': 'AR',
#   'Date': 1702960567},
#  {'City': 'guerrero negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 18.97,
#   'Humidity': 70,
#   'Cloudiness': 76,
#   'Wind Speed': 3.94,
#   'Country': 'MX',
#   'Date': 1702960506},
#  {'City': 'gura vitioarei',
#   'Lat': 45.15,
#   'Lng': 26.0333,
#   'Max Temp': 1.93,
#   'Humidity': 86,
#   'Cloudiness': 6,
#   'Wind Speed': 1.91,
#   'Country': 'RO',
#   'Date': 1702960567},
#  {'City': 'enewetak',
#   'Lat': 11.3474,
#   'Lng': 162.3373,
#   'Max Temp': 27.41,
#   'Humidity': 77,
#   'Cloudiness': 19,
#   'Wind Speed': 9.06,
#   'Country': 'MH',
#   'Date': 1702960567},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -9.91,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': 1702960568},
#  {'City': 'nabire',
#   'Lat': -3.3667,
#   'Lng': 135.4833,
#   'Max Temp': 27.33,
#   'Humidity': 88,
#   'Cloudiness': 88,
#   'Wind Speed': 2.07,
#   'Country': 'ID',
#   'Date': 1702960568},
#  {'City': 'alaghsas',
#   'Lat': 17.0187,
#   'Lng': 8.0168,
#   'Max Temp': 16.59,
#   'Humidity': 26,
#   'Cloudiness': 62,
#   'Wind Speed': 2.7,
#   'Country': 'NE',
#   'Date': 1702960568},
#  {'City': 'badger',
#   'Lat': 64.8,
#   'Lng': -147.5333,
#   'Max Temp': -12.02,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1702960568},
#  {'City': 'kota bharu',
#   'Lat': 6.1333,
#   'Lng': 102.2386,
#   'Max Temp': 32.84,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 4.63,
#   'Country': 'MY',
#   'Date': 1702960568},
#  {'City': "ust'-uda",
#   'Lat': 54.1742,
#   'Lng': 103.0304,
#   'Max Temp': -26.48,
#   'Humidity': 89,
#   'Cloudiness': 15,
#   'Wind Speed': 0.83,
#   'Country': 'RU',
#   'Date': 1702960568},
#  {'City': 'filadelfia',
#   'Lat': 39.9523,
#   'Lng': -75.1638,
#   'Max Temp': 5.94,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1702960301},
#  {'City': 'novoishimskiy',
#   'Lat': 53.1981,
#   'Lng': 66.7694,
#   'Max Temp': -12.49,
#   'Humidity': 94,
#   'Cloudiness': 94,
#   'Wind Speed': 3.81,
#   'Country': 'KZ',
#   'Date': 1702960568},
#  {'City': "nar'yan-mar",
#   'Lat': 67.6713,
#   'Lng': 53.087,
#   'Max Temp': -11.61,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': 1702960568},
#  {'City': 'port alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 18.43,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 3.52,
#   'Country': 'ZA',
#   'Date': 1702960568},
#  {'City': 'bardai',
#   'Lat': 11.65,
#   'Lng': 7.2333,
#   'Max Temp': 17.94,
#   'Humidity': 28,
#   'Cloudiness': 91,
#   'Wind Speed': 4.24,
#   'Country': 'NG',
#   'Date': 1702960569},
#  {'City': 'inari',
#   'Lat': 68.906,
#   'Lng': 27.0288,
#   'Max Temp': -11.89,
#   'Humidity': 100,
#   'Cloudiness': 67,
#   'Wind Speed': 1.56,
#   'Country': 'FI',
#   'Date': 1702960569},
#  {'City': 'hammerfest',
#   'Lat': 70.6634,
#   'Lng': 23.6821,
#   'Max Temp': -1.75,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 1.03,
#   'Country': 'NO',
#   'Date': 1702960506},
#  {'City': 'posto fiscal rolim de moura',
#   'Lat': -13.0833,
#   'Lng': -62.2667,
#   'Max Temp': 26.69,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Country': 'BR',
#   'Date': 1702960569},
#  {'City': 'nsanje',
#   'Lat': -16.92,
#   'Lng': 35.262,
#   'Max Temp': 29.06,
#   'Humidity': 66,
#   'Cloudiness': 96,
#   'Wind Speed': 2.38,
#   'Country': 'MW',
#   'Date': 1702960569},
#  {'City': 'santa cruz',
#   'Lat': -17.8,
#   'Lng': -63.1667,
#   'Max Temp': 26.7,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'BO',
#   'Date': 1702960546},
#  {'City': 'alta',
#   'Lat': 69.9689,
#   'Lng': 23.2717,
#   'Max Temp': -6.41,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 12.96,
#   'Country': 'NO',
#   'Date': 1702960569},
#  {'City': 'puerto colombia',
#   'Lat': 10.9878,
#   'Lng': -74.9547,
#   'Max Temp': 27.05,
#   'Humidity': 90,
#   'Cloudiness': 13,
#   'Wind Speed': 2.97,
#   'Country': 'CO',
#   'Date': 1702960569},
#  {'City': 'wailua homesteads',
#   'Lat': 22.0669,
#   'Lng': -159.378,
#   'Max Temp': 23.24,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 9.26,
#   'Country': 'US',
#   'Date': 1702960569},
#  {'City': 'bamboo flat',
#   'Lat': 11.7,
#   'Lng': 92.7167,
#   'Max Temp': 31.05,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Country': 'IN',
#   'Date': 1702960569},
#  {'City': 'ust-nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': -35.45,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 1.6,
#   'Country': 'RU',
#   'Date': 1702960569},
#  {'City': 'brokopondo',
#   'Lat': 4.75,
#   'Lng': -55.1667,
#   'Max Temp': 25.42,
#   'Humidity': 86,
#   'Cloudiness': 87,
#   'Wind Speed': 3.77,
#   'Country': 'SR',
#   'Date': 1702960570},
#  {'City': 'chamrajnagar',
#   'Lat': 11.9167,
#   'Lng': 76.95,
#   'Max Temp': 23.57,
#   'Humidity': 65,
#   'Cloudiness': 31,
#   'Wind Speed': 2.35,
#   'Country': 'IN',
#   'Date': 1702960570},
#  {'City': 'paita',
#   'Lat': -5.0892,
#   'Lng': -81.1144,
#   'Max Temp': 21.54,
#   'Humidity': 85,
#   'Cloudiness': 85,
#   'Wind Speed': 4.33,
#   'Country': 'PE',
#   'Date': 1702960570},
#  {'City': 'iskateley',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': -11.66,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': 1702960570},
#  {'City': 'mugia',
#   'Lat': 43.1041,
#   'Lng': -9.2179,
#   'Max Temp': 6.62,
#   'Humidity': 75,
#   'Cloudiness': 82,
#   'Wind Speed': 1.44,
#   'Country': 'ES',
#   'Date': 1702960570},
#  {'City': 'aliveri',
#   'Lat': 38.4167,
#   'Lng': 24.0333,
#   'Max Temp': 11.75,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 3.55,
#   'Country': 'GR',
#   'Date': 1702960570},
#  {'City': 'marsabit',
#   'Lat': 2.3284,
#   'Lng': 37.9899,
#   'Max Temp': 21.13,
#   'Humidity': 55,
#   'Cloudiness': 22,
#   'Wind Speed': 4.42,
#   'Country': 'KE',
#   'Date': 1702960570},
#  {'City': 'colonia',
#   'Lat': 50.9333,
#   'Lng': 6.95,
#   'Max Temp': 6.7,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'DE',
#   'Date': 1702960570},
#  {'City': 'hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': -9.41,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 2.03,
#   'Country': 'CN',
#   'Date': 1702960570},
#  {'City': 'newman',
#   'Lat': 37.3138,
#   'Lng': -121.0208,
#   'Max Temp': 14.6,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': 1702960571},
#  {'City': 'vilyuchinsk',
#   'Lat': 52.9306,
#   'Lng': 158.4028,
#   'Max Temp': -3.85,
#   'Humidity': 79,
#   'Cloudiness': 77,
#   'Wind Speed': 2.63,
#   'Country': 'RU',
#   'Date': 1702960571},
#  {'City': 'quelimane',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Max Temp': 26.97,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'MZ',
#   'Date': 1702960571},
#  {'City': 'prachuap khiri khan',
#   'Lat': 12.2167,
#   'Lng': 99.75,
#   'Max Temp': 29.65,
#   'Humidity': 53,
#   'Cloudiness': 39,
#   'Wind Speed': 3.68,
#   'Country': 'TH',
#   'Date': 1702960571},
#  {'City': 'kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 16.6,
#   'Humidity': 79,
#   'Cloudiness': 16,
#   'Wind Speed': 1.75,
#   'Country': 'ZA',
#   'Date': 1702960571},
#  {'City': 'tolanaro',
#   'Lat': -25.0319,
#   'Lng': 46.9987,
#   'Max Temp': 26.04,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 2.06,
#   'Country': 'MG',
#   'Date': 1702960571},
#  {'City': 'tazacorte',
#   'Lat': 28.629,
#   'Lng': -17.9293,
#   'Max Temp': 17.86,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'ES',
#   'Date': 1702960571},
#  {'City': 'mana',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 24.9,
#   'Humidity': 92,
#   'Cloudiness': 43,
#   'Wind Speed': 3.35,
#   'Country': 'GF',
#   'Date': 1702960571},
#  {'City': 'ghanzi',
#   'Lat': -21.5667,
#   'Lng': 21.7833,
#   'Max Temp': 23.35,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 5.26,
#   'Country': 'BW',
#   'Date': 1702960571},
#  {'City': 'dryden',
#   'Lat': 49.7833,
#   'Lng': -92.7503,
#   'Max Temp': -12.84,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'CA',
#   'Date': 1702960571},
#  {'City': 'papatowai',
#   'Lat': -46.5619,
#   'Lng': 169.4708,
#   'Max Temp': 18.36,
#   'Humidity': 59,
#   'Cloudiness': 87,
#   'Wind Speed': 3.22,
#   'Country': 'NZ',
#   'Date': 1702960572},
#  {'City': 'itoman',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 25.21,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'JP',
#   'Date': 1702960572},
#  {'City': 'todos santos',
#   'Lat': 23.45,
#   'Lng': -110.2167,
#   'Max Temp': 22.47,
#   'Humidity': 69,
#   'Cloudiness': 81,
#   'Wind Speed': 2.67,
#   'Country': 'MX',
#   'Date': 1702960572},
#  {'City': 'nogliki',
#   'Lat': 51.8333,
#   'Lng': 143.1667,
#   'Max Temp': -18.41,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.16,
#   'Country': 'RU',
#   'Date': 1702960572},
#  {'City': "arkhangel'sk",
#   'Lat': 64.5401,
#   'Lng': 40.5433,
#   'Max Temp': -2.94,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'RU',
#   'Date': 1702960572},
#  {'City': 'trapani',
#   'Lat': 37.8333,
#   'Lng': 12.6667,
#   'Max Temp': 10.15,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'IT',
#   'Date': 1702960572},
#  {'City': 'borkum',
#   'Lat': 53.5809,
#   'Lng': 6.6915,
#   'Max Temp': 8.86,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 9.7,
#   'Country': 'DE',
#   'Date': 1702960572},
#  {'City': 'galesong',
#   'Lat': -5.3166,
#   'Lng': 119.3661,
#   'Max Temp': 29.01,
#   'Humidity': 63,
#   'Cloudiness': 98,
#   'Wind Speed': 4.15,
#   'Country': 'ID',
#   'Date': 1702960572},
#  {'City': 'mbuji-mayi',
#   'Lat': -6.15,
#   'Lng': 23.6,
#   'Max Temp': 21.42,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0.82,
#   'Country': 'CD',
#   'Date': 1702960572},
#  {'City': 'celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 21.21,
#   'Humidity': 61,
#   'Cloudiness': 2,
#   'Wind Speed': 3.58,
#   'Country': 'MX',
#   'Date': 1702960573},
#  {'City': 'port said',
#   'Lat': 31.2565,
#   'Lng': 32.2841,
#   'Max Temp': 18.99,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 4.63,
#   'Country': 'EG',
#   'Date': 1702960573},
#  {'City': 'sao joao da barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 23.24,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 0.99,
#   'Country': 'BR',
#   'Date': 1702960361},
#  {'City': 'saint-pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 29.82,
#   'Humidity': 66,
#   'Cloudiness': 5,
#   'Wind Speed': 2.06,
#   'Country': 'RE',
#   'Date': 1702960373},
#  {'City': 'mananara',
#   'Lat': -16.1667,
#   'Lng': 49.7667,
#   'Max Temp': 29.32,
#   'Humidity': 62,
#   'Cloudiness': 48,
#   'Wind Speed': 1.27,
#   'Country': 'MG',
#   'Date': 1702960573},
#  {'City': 'pyt-yakh',
#   'Lat': 60.7499,
#   'Lng': 72.8582,
#   'Max Temp': -12.97,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.42,
#   'Country': 'RU',
#   'Date': 1702960573},
#  {'City': 'anna regina',
#   'Lat': 7.2644,
#   'Lng': -58.5077,
#   'Max Temp': 25.51,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 2.33,
#   'Country': 'GY',
#   'Date': 1702960573},
#  {'City': 'talodi',
#   'Lat': 10.6325,
#   'Lng': 30.3797,
#   'Max Temp': 23.96,
#   'Humidity': 30,
#   'Cloudiness': 38,
#   'Wind Speed': 2.23,
#   'Country': 'SD',
#   'Date': 1702960573},
#  {'City': 'havre',
#   'Lat': 49.5833,
#   'Lng': 0.3333,
#   'Max Temp': 7.87,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'FR',
#   'Date': 1702960573},
#  {'City': 'tsiombe',
#   'Lat': -25.3,
#   'Lng': 45.4833,
#   'Max Temp': 27.41,
#   'Humidity': 59,
#   'Cloudiness': 46,
#   'Wind Speed': 5.05,
#   'Country': 'MG',
#   'Date': 1702960573},
#  {'City': 'bayganin',
#   'Lat': 48.6947,
#   'Lng': 55.8742,
#   'Max Temp': -1.51,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.5,
#   'Country': 'KZ',
#   'Date': 1702960574},
#  {'City': 'remire-montjoly',
#   'Lat': 4.9167,
#   'Lng': -52.2667,
#   'Max Temp': 25.02,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'GF',
#   'Date': 1702960574},
#  {'City': 'nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': -7.66,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'GL',
#   'Date': 1702960380},
#  {'City': 'polyarnyy',
#   'Lat': 69.1989,
#   'Lng': 33.4478,
#   'Max Temp': -10.99,
#   'Humidity': 89,
#   'Cloudiness': 12,
#   'Wind Speed': 4.93,
#   'Country': 'RU',
#   'Date': 1702960574},
#  {'City': 'pekan',
#   'Lat': 3.4836,
#   'Lng': 103.3996,
#   'Max Temp': 27.06,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.65,
#   'Country': 'MY',
#   'Date': 1702960574},
#  {'City': 'la passe',
#   'Lat': 45.5549,
#   'Lng': -0.8967,
#   'Max Temp': 3.13,
#   'Humidity': 86,
#   'Cloudiness': 19,
#   'Wind Speed': 0.9,
#   'Country': 'FR',
#   'Date': 1702960574},
#  {'City': 'fallon',
#   'Lat': 39.4735,
#   'Lng': -118.7774,
#   'Max Temp': 1.93,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1702960534},
#  {'City': 'karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 30.81,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 8.04,
#   'Country': 'AU',
#   'Date': 1702960574},
#  {'City': 'kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 27.66,
#   'Humidity': 72,
#   'Cloudiness': 68,
#   'Wind Speed': 0.49,
#   'Country': 'SB',
#   'Date': 1702960574},
#  {'City': 'coquimatlan',
#   'Lat': 19.2,
#   'Lng': -103.8,
#   'Max Temp': 21.23,
#   'Humidity': 85,
#   'Cloudiness': 4,
#   'Wind Speed': 1.28,
#   'Country': 'MX',
#   'Date': 1702960574},
#  {'City': 'melfi',
#   'Lat': 40.9965,
#   'Lng': 15.6514,
#   'Max Temp': 5.55,
#   'Humidity': 50,
#   'Cloudiness': 2,
#   'Wind Speed': 1.34,
#   'Country': 'IT',
#   'Date': 1702960574},
#  {'City': 'abilene',
#   'Lat': 32.4487,
#   'Lng': -99.7331,
#   'Max Temp': 8.3,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1702960499},
#  {'City': 'linevo',
#   'Lat': 54.4589,
#   'Lng': 83.3764,
#   'Max Temp': -15.89,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 5.26,
#   'Country': 'RU',
#   'Date': 1702960575},
#  {'City': 'gargalianoi',
#   'Lat': 37.0667,
#   'Lng': 21.6333,
#   'Max Temp': 1.34,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 0.62,
#   'Country': 'GR',
#   'Date': 1702960575},
#  {'City': 'prince rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 6.83,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'CA',
#   'Date': 1702960575},
#  {'City': 'bossangoa',
#   'Lat': 6.4926,
#   'Lng': 17.4552,
#   'Max Temp': 21.2,
#   'Humidity': 34,
#   'Cloudiness': 100,
#   'Wind Speed': 0.82,
#   'Country': 'CF',
#   'Date': 1702960575},
#  {'City': 'udachny',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': -28.26,
#   'Humidity': 95,
#   'Cloudiness': 82,
#   'Wind Speed': 1.45,
#   'Country': 'RU',
#   'Date': 1702960575},
#  {'City': 'chernyshevskiy',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': -34.49,
#   'Humidity': 99,
#   'Cloudiness': 86,
#   'Wind Speed': 1.18,
#   'Country': 'RU',
#   'Date': 1702960575},
#  {'City': 'nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': -3.49,
#   'Humidity': 55,
#   'Cloudiness': 30,
#   'Wind Speed': 6.11,
#   'Country': 'JP',
#   'Date': 1702960575},
#  {'City': 'gilmer',
#   'Lat': 32.7287,
#   'Lng': -94.9424,
#   'Max Temp': 7.1,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1702960575},
#  {'City': 'boden',
#   'Lat': 65.8252,
#   'Lng': 21.6886,
#   'Max Temp': 1,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.21,
#   'Country': 'SE',
#   'Date': 1702960575},
#  {'City': 'antonio enes',
#   'Lat': -16.2325,
#   'Lng': 39.9086,
#   'Max Temp': 28.97,
#   'Humidity': 68,
#   'Cloudiness': 94,
#   'Wind Speed': 1.49,
#   'Country': 'MZ',
#   'Date': 1702960576},
#  {'City': 'vila franca do campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 17.23,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.46,
#   'Country': 'PT',
#   'Date': 1702960576},
#  {'City': 'bima',
#   'Lat': -8.4667,
#   'Lng': 118.7167,
#   'Max Temp': 33.95,
#   'Humidity': 44,
#   'Cloudiness': 65,
#   'Wind Speed': 2.41,
#   'Country': 'ID',
#   'Date': 1702960576},
#  {'City': 'pangoa',
#   'Lat': -12.1167,
#   'Lng': -73,
#   'Max Temp': 21.09,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'PE',
#   'Date': 1702960576},
#  {'City': 'klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 2.51,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 7.64,
#   'Country': 'FO',
#   'Date': 1702960576},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 32.75,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Country': 'MY',
#   'Date': 1702960564},
#  {'City': 'charters towers',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 33.77,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 7,
#   'Country': 'AU',
#   'Date': 1702960576},
#  {'City': 'ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 5.99,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1702960576},
#  {'City': 'fort bragg',
#   'Lat': 35.139,
#   'Lng': -79.006,
#   'Max Temp': 6.91,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1702960576},
#  {'City': 'northam',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 12.99,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.6,
#   'Country': 'GB',
#   'Date': 1702960577},
#  {'City': 'puerto san jose',
#   'Lat': 13.9256,
#   'Lng': -90.8244,
#   'Max Temp': 22.03,
#   'Humidity': 57,
#   'Cloudiness': 11,
#   'Wind Speed': 2.96,
#   'Country': 'GT',
#   'Date': 1702960577},
#  {'City': 'tazovsky',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': -14.07,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Country': 'RU',
#   'Date': 1702960577},
#  {'City': 'merritt',
#   'Lat': 50.1123,
#   'Lng': -120.7942,
#   'Max Temp': 2.4,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'CA',
#   'Date': 1702960577},
#  {'City': 'owen sound',
#   'Lat': 44.5672,
#   'Lng': -80.9435,
#   'Max Temp': -2.84,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.49,
#   'Country': 'CA',
#   'Date': 1702960504},
# ...
#   'Date': 1702960596},
#  {'City': 'lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 28.79,
#   'Humidity': 76,
#   'Cloudiness': 79,
#   'Wind Speed': 3.72,
#   'Country': 'PG',
#   'Date': 1702960596},
#  {'City': 'camarinas',
#   'Lat': 43.1311,
#   'Lng': -9.1817,
#   'Max Temp': 6.63,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 1.45,
#   'Country': 'ES',
#   'Date': 1702960597},
#  {'City': 'jurbarkas',
#   'Lat': 55.0778,
#   'Lng': 22.7664,
#   'Max Temp': 6.98,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.86,
#   'Country': 'LT',
#   'Date': 1702960597},
#  {'City': 'novyy urengoy',
#   'Lat': 66.0833,
#   'Lng': 76.6333,
#   'Max Temp': -13.81,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.43,
#   'Country': 'RU',
#   'Date': 1702960597},
#  {'City': 'zheshart',
#   'Lat': 62.0731,
#   'Lng': 49.5733,
#   'Max Temp': -4.06,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 2.73,
#   'Country': 'RU',
#   'Date': 1702960597},
#  {'City': 'anatuya',
#   'Lat': -28.4606,
#   'Lng': -62.8347,
#   'Max Temp': 15.4,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 8.17,
#   'Country': 'AR',
#   'Date': 1702960597},
#  {'City': 'tralee',
#   'Lat': 52.2704,
#   'Lng': -9.7026,
#   'Max Temp': 8.64,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.73,
#   'Country': 'IE',
#   'Date': 1702960328},
#  {'City': 'andergrove',
#   'Lat': -21.0833,
#   'Lng': 149.1833,
#   'Max Temp': 32.03,
#   'Humidity': 68,
#   'Cloudiness': 8,
#   'Wind Speed': 5,
#   'Country': 'AU',
#   'Date': 1702960597},
#  {'City': 'douz',
#   'Lat': 33.4663,
#   'Lng': 9.0203,
#   'Max Temp': 11.15,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 3.68,
#   'Country': 'TN',
#   'Date': 1702960597},
#  {'City': 'papao',
#   'Lat': -17.75,
#   'Lng': -149.55,
#   'Max Temp': 26.82,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 1.03,
#   'Country': 'PF',
#   'Date': 1702960597},
#  {'City': 'sao sepe',
#   'Lat': -30.1606,
#   'Lng': -53.5653,
#   'Max Temp': 22.35,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.29,
#   'Country': 'BR',
#   'Date': 1702960596},
#  {'City': 'boa vista',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 28.99,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'BR',
#   'Date': 1702960598},
#  {'City': 'valdivia',
#   'Lat': -39.8142,
#   'Lng': -73.2459,
#   'Max Temp': 13.05,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 1.59,
#   'Country': 'CL',
#   'Date': 1702960326},
#  {'City': 'katsina-ala',
#   'Lat': 7.1667,
#   'Lng': 9.2833,
#   'Max Temp': 21.78,
#   'Humidity': 29,
#   'Cloudiness': 10,
#   'Wind Speed': 1.45,
#   'Country': 'NG',
#   'Date': 1702960598},
#  {'City': 'kinarut',
#   'Lat': 5.8231,
#   'Lng': 116.0466,
#   'Max Temp': 32.01,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 2.06,
#   'Country': 'MY',
#   'Date': 1702960598},
#  {'City': 'lazaro cardenas',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 24.52,
#   'Humidity': 86,
#   'Cloudiness': 8,
#   'Wind Speed': 1.68,
#   'Country': 'MX',
#   'Date': 1702960598},
#  {'City': 'troitsko-pechorsk',
#   'Lat': 62.7084,
#   'Lng': 56.1964,
#   'Max Temp': -10.17,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58,
#   'Country': 'RU',
#   'Date': 1702960598},
#  {'City': 'sanctuary point',
#   'Lat': -35.1114,
#   'Lng': 150.629,
#   'Max Temp': 28.32,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 6.2,
#   'Country': 'AU',
#   'Date': 1702960598},
#  {'City': 'ushtobe',
#   'Lat': 45.2514,
#   'Lng': 77.9838,
#   'Max Temp': -2.29,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'KZ',
#   'Date': 1702960598},
#  {'City': 'santa terezinha',
#   'Lat': -29.9002,
#   'Lng': -50.0904,
#   'Max Temp': 22.72,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 2.14,
#   'Country': 'BR',
#   'Date': 1702960598},
#  {'City': 'howrah',
#   'Lat': 22.5892,
#   'Lng': 88.3103,
#   'Max Temp': 19,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Country': 'IN',
#   'Date': 1702960598},
#  {'City': 'moshi',
#   'Lat': -3.35,
#   'Lng': 37.3333,
#   'Max Temp': 23.02,
#   'Humidity': 78,
#   'Cloudiness': 65,
#   'Wind Speed': 1.18,
#   'Country': 'TZ',
#   'Date': 1702960599},
#  {'City': 'itambe',
#   'Lat': -15.245,
#   'Lng': -40.6244,
#   'Max Temp': 18.41,
#   'Humidity': 98,
#   'Cloudiness': 21,
#   'Wind Speed': 0.03,
#   'Country': 'BR',
#   'Date': 1702960599},
#  {'City': 'nyurba',
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': -26.11,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.59,
#   'Country': 'RU',
#   'Date': 1702960399},
#  {'City': 'round rock',
#   'Lat': 30.5083,
#   'Lng': -97.6789,
#   'Max Temp': 11.96,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1702960501},
#  {'City': 'rovaniemi',
#   'Lat': 66.5,
#   'Lng': 25.7167,
#   'Max Temp': -4.33,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'FI',
#   'Date': 1702960599},
#  {'City': 'slave lake',
#   'Lat': 55.2834,
#   'Lng': -114.769,
#   'Max Temp': -3.01,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'CA',
#   'Date': 1702960599},
#  {'City': 'palopo',
#   'Lat': -2.9996,
#   'Lng': 120.1921,
#   'Max Temp': 29.37,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 2.14,
#   'Country': 'ID',
#   'Date': 1702960599},
#  {'City': 'touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 26.11,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58,
#   'Country': 'BR',
#   'Date': 1702960423},
#  {'City': 'malango',
#   'Lat': -2.9627,
#   'Lng': 119.9001,
#   'Max Temp': 27.25,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 1.15,
#   'Country': 'ID',
#   'Date': 1702960599},
#  {'City': 'el kala',
#   'Lat': 36.8956,
#   'Lng': 8.4433,
#   'Max Temp': 9.23,
#   'Humidity': 88,
#   'Cloudiness': 88,
#   'Wind Speed': 1.11,
#   'Country': 'DZ',
#   'Date': 1702960599},
#  {'City': "mil'kovo",
#   'Lat': 55.6078,
#   'Lng': 37.7956,
#   'Max Temp': 2.08,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.17,
#   'Country': 'RU',
#   'Date': 1702960599},
#  {'City': 'bahia de kino',
#   'Lat': 28.8333,
#   'Lng': -111.9333,
#   'Max Temp': 16.07,
#   'Humidity': 37,
#   'Cloudiness': 92,
#   'Wind Speed': 3.24,
#   'Country': 'MX',
#   'Date': 1702960600},
#  {'City': 'katabu',
#   'Lat': -4.9333,
#   'Lng': 122.5167,
#   'Max Temp': 31.28,
#   'Humidity': 60,
#   'Cloudiness': 82,
#   'Wind Speed': 3.76,
#   'Country': 'ID',
#   'Date': 1702960600},
#  {'City': 'zhangatas',
#   'Lat': 43.5667,
#   'Lng': 69.75,
#   'Max Temp': -1.46,
#   'Humidity': 88,
#   'Cloudiness': 82,
#   'Wind Speed': 9.9,
#   'Country': 'KZ',
#   'Date': 1702960600},
#  {'City': 'villa yapacani',
#   'Lat': -17.4,
#   'Lng': -63.8333,
#   'Max Temp': 24.77,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.37,
#   'Country': 'BO',
#   'Date': 1702960600},
#  {'City': 'struer',
#   'Lat': 56.4912,
#   'Lng': 8.5838,
#   'Max Temp': 8.26,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 5.79,
#   'Country': 'DK',
#   'Date': 1702960600},
#  {'City': 'ranot',
#   'Lat': 7.7777,
#   'Lng': 100.3213,
#   'Max Temp': 28.54,
#   'Humidity': 70,
#   'Cloudiness': 31,
#   'Wind Speed': 4.94,
#   'Country': 'TH',
#   'Date': 1702960600},
#  {'City': 'murghob',
#   'Lat': 38.1702,
#   'Lng': 73.9667,
#   'Max Temp': -15.52,
#   'Humidity': 56,
#   'Cloudiness': 38,
#   'Wind Speed': 1.06,
#   'Country': 'TJ',
#   'Date': 1702960600},
#  {'City': 'khanty-mansiysk',
#   'Lat': 61.0042,
#   'Lng': 69.0019,
#   'Max Temp': -11.94,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 5,
#   'Country': 'RU',
#   'Date': 1702960600},
#  {'City': 'zhangzhou',
#   'Lat': 24.5133,
#   'Lng': 117.6556,
#   'Max Temp': 18.96,
#   'Humidity': 55,
#   'Cloudiness': 6,
#   'Wind Speed': 1.71,
#   'Country': 'CN',
#   'Date': 1702960600},
#  {'City': 'akjoujt',
#   'Lat': 19.6969,
#   'Lng': -14.4164,
#   'Max Temp': 12.3,
#   'Humidity': 26,
#   'Cloudiness': 55,
#   'Wind Speed': 5.39,
#   'Country': 'MR',
#   'Date': 1702960600},
#  {'City': 'queenstown',
#   'Lat': -31.8976,
#   'Lng': 26.8753,
#   'Max Temp': 15.32,
#   'Humidity': 68,
#   'Cloudiness': 54,
#   'Wind Speed': 1.73,
#   'Country': 'ZA',
#   'Date': 1702960600},
#  {'City': 'bourbon-lancy',
#   'Lat': 46.6221,
#   'Lng': 3.7695,
#   'Max Temp': -2.17,
#   'Humidity': 87,
#   'Cloudiness': 35,
#   'Wind Speed': 0.49,
#   'Country': 'FR',
#   'Date': 1702960601},
#  {'City': 'north platte',
#   'Lat': 41.1239,
#   'Lng': -100.7654,
#   'Max Temp': 2.36,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 7.6,
#   'Country': 'US',
#   'Date': 1702960412},
#  {'City': 'corning',
#   'Lat': 42.1428,
#   'Lng': -77.0547,
#   'Max Temp': 4.02,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1702960405},
#  {'City': 'arvayheer',
#   'Lat': 46.2639,
#   'Lng': 102.775,
#   'Max Temp': -21.72,
#   'Humidity': 60,
#   'Cloudiness': 2,
#   'Wind Speed': 0.47,
#   'Country': 'MN',
#   'Date': 1702960601},
#  {'City': 'dalandzadgad',
#   'Lat': 43.5708,
#   'Lng': 104.425,
#   'Max Temp': -18.07,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 1.81,
#   'Country': 'MN',
#   'Date': 1702960601},
#  {'City': 'bowen',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 27.88,
#   'Humidity': 65,
#   'Cloudiness': 3,
#   'Wind Speed': 7.34,
#   'Country': 'AU',
#   'Date': 1702960524},
#  {'City': 'along',
#   'Lat': 28.1667,
#   'Lng': 94.7667,
#   'Max Temp': 22.41,
#   'Humidity': 35,
#   'Cloudiness': 11,
#   'Wind Speed': 0.64,
#   'Country': 'IN',
#   'Date': 1702960601},
#  {'City': 'ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 37.65,
#   'Humidity': 54,
#   'Cloudiness': 99,
#   'Wind Speed': 2.33,
#   'Country': 'AU',
#   'Date': 1702960601},
#  {'City': 'monroe',
#   'Lat': 43.1501,
#   'Lng': -77.6831,
#   'Max Temp': 2.7,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': 1702960409},
#  {'City': 'elverum',
#   'Lat': 60.8819,
#   'Lng': 11.5623,
#   'Max Temp': -1.8,
#   'Humidity': 78,
#   'Cloudiness': 28,
#   'Wind Speed': 2.74,
#   'Country': 'NO',
#   'Date': 1702960601},
#  {'City': 'lagodekhi',
#   'Lat': 41.8268,
#   'Lng': 46.2767,
#   'Max Temp': -1.5,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 1.7,
#   'Country': 'GE',
#   'Date': 1702960601},
#  {'City': 'puerto baquerizo moreno',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 24.1,
#   'Humidity': 89,
#   'Cloudiness': 86,
#   'Wind Speed': 5.07,
#   'Country': 'EC',
#   'Date': 1702960348},
#  {'City': 'gijang',
#   'Lat': 35.2442,
#   'Lng': 129.2139,
#   'Max Temp': 2.85,
#   'Humidity': 29,
#   'Cloudiness': 100,
#   'Wind Speed': 1.98,
#   'Country': 'KR',
#   'Date': 1702960601},
#  {'City': 'amungan',
#   'Lat': 15.3652,
#   'Lng': 119.9582,
#   'Max Temp': 31.53,
#   'Humidity': 58,
#   'Cloudiness': 57,
#   'Wind Speed': 0.35,
#   'Country': 'PH',
#   'Date': 1702960601},
#  {'City': 'chos malal',
#   'Lat': -37.3781,
#   'Lng': -70.2709,
#   'Max Temp': 12.99,
#   'Humidity': 51,
#   'Cloudiness': 22,
#   'Wind Speed': 3.61,
#   'Country': 'AR',
#   'Date': 1702960602},
#  {'City': 'wuhai',
#   'Lat': 39.6647,
#   'Lng': 106.8122,
#   'Max Temp': -13.02,
#   'Humidity': 56,
#   'Cloudiness': 2,
#   'Wind Speed': 3.71,
#   'Country': 'CN',
#   'Date': 1702960602},
#  {'City': 'adigrat',
#   'Lat': 14.277,
#   'Lng': 39.462,
#   'Max Temp': 13.41,
#   'Humidity': 58,
#   'Cloudiness': 23,
#   'Wind Speed': 0.7,
#   'Country': 'ET',
#   'Date': 1702960488},
#  {'City': 'san rafael',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 14.19,
#   'Humidity': 44,
#   'Cloudiness': 83,
#   'Wind Speed': 2.35,
#   'Country': 'AR',
#   'Date': 1702960602},
#  {'City': 'al hufuf',
#   'Lat': 25.3646,
#   'Lng': 49.5653,
#   'Max Temp': 18.19,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'SA',
#   'Date': 1702960602},
#  {'City': 'prince george',
#   'Lat': 53.9166,
#   'Lng': -122.753,
#   'Max Temp': 0.9,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'CA',
#   'Date': 1702960569},
#  {'City': 'olyokminsk',
#   'Lat': 60.3736,
#   'Lng': 120.4264,
#   'Max Temp': -26.02,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.72,
#   'Country': 'RU',
#   'Date': 1702960522},
#  {'City': 'imperatriz',
#   'Lat': -5.5264,
#   'Lng': -47.4917,
#   'Max Temp': 25.03,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'BR',
#   'Date': 1702960602},
#  {'City': 'comodoro rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 16.92,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'AR',
#   'Date': 1702960602},
#  {'City': 'ishigaki',
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 25.07,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'JP',
#   'Date': 1702960602},
#  {'City': 'canmore',
#   'Lat': 51.0834,
#   'Lng': -115.3521,
#   'Max Temp': 1.06,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'CA',
#   'Date': 1702960602},
#  {'City': 'mahina',
#   'Lat': -17.5065,
#   'Lng': -149.489,
#   'Max Temp': 26.87,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'PF',
#   'Date': 1702960602},
#  {'City': 'bandipura',
#   'Lat': 34.4167,
#   'Lng': 74.65,
#   'Max Temp': 6.65,
#   'Humidity': 22,
#   'Cloudiness': 9,
#   'Wind Speed': 1.07,
#   'Country': 'IN',
#   'Date': 1702960603},
#  {'City': 'bhanpura',
#   'Lat': 24.513,
#   'Lng': 75.7469,
#   'Max Temp': 17.93,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 3.21,
#   'Country': 'IN',
#   'Date': 1702960603},
#  {'City': 'pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 28.06,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 7.72,
#   'Country': 'TO',
#   'Date': 1702960603},
#  {'City': 'tindouf',
#   'Lat': 27.6711,
#   'Lng': -8.1474,
#   'Max Temp': 5.25,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'DZ',
#   'Date': 1702960603},
#  {'City': 'usinsk',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': -11.07,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.49,
#   'Country': 'RU',
#   'Date': 1702960603},
#  {'City': 'mili',
#   'Lat': 6.0815,
#   'Lng': 171.735,
#   'Max Temp': 26.81,
#   'Humidity': 88,
#   'Cloudiness': 85,
#   'Wind Speed': 8.28,
#   'Country': 'MH',
#   'Date': 1702960603},
#  {'City': 'katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 10.01,
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 3.53,
#   'Country': 'JP',
#   'Date': 1702960603},
#  {'City': 'deshnoke',
#   'Lat': 27.8,
#   'Lng': 73.35,
#   'Max Temp': 18.01,
#   'Humidity': 26,
#   'Cloudiness': 17,
#   'Wind Speed': 0.84,
#   'Country': 'IN',
#   'Date': 1702960603},
#  {'City': 'cam ranh',
#   'Lat': 11.9214,
#   'Lng': 109.1591,
#   'Max Temp': 28.98,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 8.75,
#   'Country': 'VN',
#   'Date': 1702960603},
#  {'City': 'borgarnes',
#   'Lat': 64.5383,
#   'Lng': -21.9206,
#   'Max Temp': 1.03,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.58,
#   'Country': 'IS',
#   'Date': 1702960603},
#  {'City': 'korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': -5.07,
#   'Humidity': 54,
#   'Cloudiness': 3,
#   'Wind Speed': 0.94,
#   'Country': 'CN',
#   'Date': 1702960603},
#  {'City': 'dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 16.84,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 4.82,
#   'Country': 'NZ',
#   'Date': 1702960603},
#  {'City': 'kuching',
#   'Lat': 1.55,
#   'Lng': 110.3333,
#   'Max Temp': 32.34,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 1.54,
#   'Country': 'MY',
#   'Date': 1702960604},
#  {'City': 'solvang',
#   'Lat': 34.5958,
#   'Lng': -120.1377,
#   'Max Temp': 17.04,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1702960604},
#  {'City': 'vila velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 21.97,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'BR',
#   'Date': 1702960604},
#  {'City': 'namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 22.8,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 1.8,
#   'Country': 'AO',
#   'Date': 1702960604},
#  {'City': 'kulachi',
#   'Lat': 31.9286,
#   'Lng': 70.4592,
#   'Max Temp': 19.1,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 1.23,
#   'Country': 'PK',
#   'Date': 1702960604},
#  {'City': 'tadine',
#   'Lat': -21.55,
#   'Lng': 167.8833,
#   'Max Temp': 24.66,
#   'Humidity': 85,
#   'Cloudiness': 72,
#   'Wind Speed': 10.47,
#   'Country': 'NC',
#   'Date': 1702960604},
#  {'City': 'onega',
#   'Lat': 63.9061,
#   'Lng': 38.1404,
#   'Max Temp': -1.2,
#   'Humidity': 96,
#   'Cloudiness': 98,
#   'Wind Speed': 3.24,
#   'Country': 'RU',
#   'Date': 1702960604}]

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)
city_data_pd.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          adamstown -25.0660 -130.1015     22.82        81         100
# 1     puerto natales -51.7236  -72.4875      8.45        83          97
# 2            la mira  18.0350 -102.3266     23.73        89           7
# 3             bethel  41.3712  -73.4140      6.40        77           0
# 4  port-aux-francais -49.3500   70.2167      6.10        74          56
#
#    Wind Speed Country        Date
# 0        6.68      PN  1702960281
# 1        1.83      CL  1702960552
# 2        1.69      MX  1702960553
# 3        4.12      US  1702960417
# 4       12.09      TF  1702960523

# %%
# Extract relevant fields from the DataFrame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# print(lats)
# print(max_temps)
# print(humidity)
# print(cloudiness)
# print(wind_speed)

# %%
# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     22.82        81         100
# 1           puerto natales -51.7236  -72.4875      8.45        83          97
# 2                  la mira  18.0350 -102.3266     23.73        89           7
# 3                   bethel  41.3712  -73.4140      6.40        77           0
# 4        port-aux-francais -49.3500   70.2167      6.10        74          56
#
#          Wind Speed Country        Date
# City_ID
# 0              6.68      PN  1702960281
# 1              1.83      CL  1702960552
# 2              1.69      MX  1702960553
# 3              4.12      US  1702960417
# 4             12.09      TF  1702960523

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"],
            edgecolor="black", linewidth=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature ({time.strftime('%x')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],
            edgecolor="black", linewidth=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Humidity ({time.strftime('%x')})")
plt.xlabel("Latitude")
plt.ylabel("Max Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],
            edgecolor="black", linewidth=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({time.strftime('%x')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],
            edgecolor="black", linewidth=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({time.strftime('%x')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#takes in as arguments a DataFrame (df), the x-axis String column name (x_Col), and the y-axis String column name (y_Col)
#plots a scatter plot with the df[x_Col] on the x-axis and the df[y_Col] data on the y-axis, and the linear regression line
#prints information about the best fit line from the linear regression
#returns the axes object for the plot, so more changes can be made later if necessary
def makeLinRegression(df, x_Col, y_Col):
    #first, perform the linear regression on the data
    (regr_slope, regr_intercept, regr_r_val, _, _) = linregress(df[x_Col], 
                                                           df[y_Col])
    #setup the linear regression line x and y axes data points
    regr_line_x = np.array([a for a in range(int(min(df[x_Col].values)), int(max(df[x_Col].values)+1))])
    regr_line_y = regr_slope * regr_line_x + regr_intercept

    #plot the scatterplot with the raw data first!
    df_axes = df.plot(kind="scatter", x=x_Col, y=y_Col, 
                      title="{} vs. {} ({})"
                        .format(y_Col, x_Col, remaining_cities["Datetime (Local)"].iloc[0].split(",")[0]))

    #add the best fit lines to the plot as a solid red line
    df_axes.plot(regr_line_x, regr_line_y, 'r')

    #output best-fit line information
    print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
          .format(regr_slope, regr_intercept))
    print("The r-squared correlation coefficient for this line is {:.2f}".format(regr_r_val))
                  
    #return the axes object for the plots, in case any changes need to be made
    return df_axes

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)

#first, get a subset of all the cities that are on or north of the equator for the Northern Hemisphere DataFrame
northern_hemisphere = city_data_df.loc[(city_data_df["Lat"] >= 0)]
    
# Display sample data
northern_hemisphere.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                       la mira  18.0350 -102.3266     23.73        89
# 3                        bethel  41.3712  -73.4140      6.40        77
# 6                       stanley  54.8680   -1.6985      8.49        91
# 7                    isafjordur  66.0755  -23.1240     -2.78        84
# 8        hawaiian paradise park  19.5933 -154.9731     21.73        92
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                 7        1.69      MX  1702960553
# 3                 0        4.12      US  1702960417
# 6                75        3.60      GB  1702960553
# 7                99        2.72      IS  1702960553
# 8                40        2.57      US  1702960553

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
#first, get a subset of all the cities that are south of the equator for the Southern Hemisphere DataFrame
southern_hemisphere = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemisphere.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     22.82        81         100
# 1           puerto natales -51.7236  -72.4875      8.45        83          97
# 4        port-aux-francais -49.3500   70.2167      6.10        74          56
# 5               bredasdorp -34.5322   20.0403     17.10        62           0
# 12            puerto ayora  -0.7393  -90.3518     24.75        95          47
#
#          Wind Speed Country        Date
# City_ID
# 0              6.68      PN  1702960281
# 1              1.83      CL  1702960552
# 4             12.09      TF  1702960523
# 5              2.40      ZA  1702960553
# 12             0.89      EC  1702960286

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
(n_temp_slope, n_temp_intercept, n_temp_r_val, _, _) = linregress(northern_hemisphere["Lat"], 
                                                           northern_hemisphere["Max Temp"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_temp_slope * regr_line_x + n_temp_intercept

n_temp_axes = northern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Max Temp", 
                                       title="Max Temp vs. Lat")                 

n_temp_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(n_temp_slope, n_temp_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(n_temp_r_val))
n_temp_axes.get_figure().savefig("Fig5.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=-0.65x+30.93
# The r-squared correlation coefficient for this line is -0.82

# %%
# Linear regression on Southern Hemisphere
(s_temp_slope, s_temp_intercept, s_temp_r_val, _, _) = linregress(southern_hemisphere["Lat"], 
                                                           southern_hemisphere["Max Temp"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_temp_slope * regr_line_x + s_temp_intercept

s_temp_axes = southern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Max Temp", 
                                       title="Max Temp vs. Lat")                 

s_temp_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(s_temp_slope, s_temp_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(s_temp_r_val))
s_temp_axes.get_figure().savefig("Fig6.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=0.31x+30.37
# The r-squared correlation coefficient for this line is 0.62

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(n_humidity_slope, n_humidity_intercept, n_humidity_r_val, _, _) = linregress(northern_hemisphere["Lat"], 
                                                           northern_hemisphere["Humidity"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_temp_slope * regr_line_x + n_temp_intercept

n_humidity_axes = northern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Humidity", 
                                       title="Humidity vs. Lat")                 

n_humidity_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(n_humidity_slope, n_humidity_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(n_humidity_r_val))
n_humidity_axes.get_figure().savefig("Fig7.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=0.43x+58.12
# The r-squared correlation coefficient for this line is 0.42

# %%
# Southern Hemisphere
(s_humidity_slope, s_humidity_intercept, s_humidity_r_val, _, _) = linregress(southern_hemisphere["Lat"], 
                                                           southern_hemisphere["Humidity"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_humidity_slope * regr_line_x + s_humidity_intercept

s_humidity_axes = southern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Humidity", 
                                       title="Humidity vs. Lat")                 

s_humidity_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(s_humidity_slope, s_humidity_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(s_humidity_r_val))
s_humidity_axes.get_figure().savefig("Fig8.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=0.32x+79.70
# The r-squared correlation coefficient for this line is 0.25

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(n_cloudiness_slope, n_cloudiness_intercept, n_cloudiness_r_val, _, _) = linregress(northern_hemisphere["Lat"], 
                                                           northern_hemisphere["Cloudiness"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_cloudiness_slope * regr_line_x + n_cloudiness_intercept

n_cloudiness_axes = northern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Cloudiness", 
                                       title="Cloudiness vs. Lat")                 

n_cloudiness_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(n_cloudiness_slope, n_cloudiness_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(n_cloudiness_r_val))
n_cloudiness_axes.get_figure().savefig("Fig9.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=0.56x+40.16
# The r-squared correlation coefficient for this line is 0.27

# %%
# Southern Hemisphere
(s_cloudiness_slope, s_cloudiness_intercept, s_cloudiness_r_val, _, _) = linregress(southern_hemisphere["Lat"], 
                                                           southern_hemisphere["Cloudiness"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_cloudiness_slope * regr_line_x + s_cloudiness_intercept

s_cloudiness_axes = southern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Cloudiness", 
                                       title="Cloudiness vs. Lat")                 

s_cloudiness_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(s_cloudiness_slope, s_cloudiness_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(s_cloudiness_r_val))
s_cloudiness_axes.get_figure().savefig("Fig10.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=0.72x+76.87
# The r-squared correlation coefficient for this line is 0.27

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(n_wind_slope, n_wind_intercept, n_wind_r_val, _, _) = linregress(northern_hemisphere["Lat"], 
                                                           northern_hemisphere["Wind Speed"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = n_wind_slope * regr_line_x + n_wind_intercept

n_wind_axes = northern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Wind Speed", 
                                       title="Wind Speed vs. Lat")                 

n_wind_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(n_wind_slope, n_wind_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(n_wind_r_val))
n_wind_axes.get_figure().savefig("Fig11.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=0.02x+3.32
# The r-squared correlation coefficient for this line is 0.12

# %%
# Southern Hemisphere
(s_wind_slope, s_wind_intercept, s_wind_r_val, _, _) = linregress(southern_hemisphere["Lat"], 
                                                           southern_hemisphere["Wind Speed"])

regr_line_x = np.array([a for a in range(80)])
regr_line_y = s_wind_slope * regr_line_x + s_wind_intercept

s_wind_axes = southern_hemisphere.plot(kind="scatter", x="Lat", 
                                       y="Wind Speed", 
                                       title="Wind Speed vs. Lat")                 

s_wind_axes.plot(regr_line_x, regr_line_y, 'r')

print("The equation of the best-fit linear regression line for this chart is y={:.2f}x+{:.2f}"
      .format(s_wind_slope, s_wind_intercept))
print("The r-squared correlation coefficient for this line is {:.2f}".format(s_wind_r_val))
s_wind_axes.get_figure().savefig("Fig12.png")
# Out:
# The equation of the best-fit linear regression line for this chart is y=-0.07x+2.41
# The r-squared correlation coefficient for this line is -0.37

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
