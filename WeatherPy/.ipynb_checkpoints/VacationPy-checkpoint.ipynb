# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# cartopy, geoviews, pyproj.

# %%
# pip install pyproj
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# Geoapify API key
geoapify_key = "495b3e6e80d5434aa4e1b5f24872ca89"
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Display sample data
city_data_df.head(10)
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0               adamstown -25.0660 -130.1015     22.82        81
# 1        1          puerto natales -51.7236  -72.4875      8.45        83
# 2        2                 la mira  18.0350 -102.3266     23.73        89
# 3        3                  bethel  41.3712  -73.4140      6.40        77
# 4        4       port-aux-francais -49.3500   70.2167      6.10        74
# 5        5              bredasdorp -34.5322   20.0403     17.10        62
# 6        6                 stanley  54.8680   -1.6985      8.49        91
# 7        7              isafjordur  66.0755  -23.1240     -2.78        84
# 8        8  hawaiian paradise park  19.5933 -154.9731     21.73        92
# 9        9                  wonsan  39.1528  127.4436     -2.36        66
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        6.68      PN  1702960281
# 1          97        1.83      CL  1702960552
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Vacation_Map
vac_map=city_data_df.hvplot.points("Lng", "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
                                  )
vac_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
c_data_df = pd.DataFrame(city_data_df, columns = ["City", "Max Temp", "Wind Speed", "Cloudiness"])

max_temp = (c_data_df["Max Temp"] <= 27) & (c_data_df["Max Temp"] > 21)
wind_speed = c_data_df["Wind Speed"] < 4.5
cloudiness = c_data_df["Cloudiness"] == 0

# city_data_df[max_temp & wind_speed & cloudiness]
ideal_weather_df = c_data_df[max_temp & wind_speed & cloudiness]
ideal_weather_df
# Out:
#                   City  Max Temp  Wind Speed  Cloudiness
# 29         kailua-kona     22.98        3.60           0
# 67             samitah     24.39        0.93           0
# 221  sao joao da barra     23.24        0.99           0
# 425             macapa     26.99        1.54           0
# 440    arraial do cabo     23.12        3.57           0
# 444             jeddah     22.92        0.00           0
# 524         imperatriz     25.03        1.54           0

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[["City", "Lat", "Lng", "Country", "Humidity"]].copy()

hotel_df["Hotel Name"] = ""
# hotel_df["Coordinates"] = ""
hotel_df
# Out:
#                   City      Lat       Lng Country  Humidity Hotel Name
# 0            adamstown -25.0660 -130.1015      PN        81
# 1       puerto natales -51.7236  -72.4875      CL        83
# 2              la mira  18.0350 -102.3266      MX        89
# 3               bethel  41.3712  -73.4140      US        77
# 4    port-aux-francais -49.3500   70.2167      TF        74
# ..                 ...      ...       ...     ...       ...        ...
# 543         vila velha -20.3297  -40.2925      BR        94
# 544             namibe -15.1961   12.1522      AO        81
# 545            kulachi  31.9286   70.4592      PK        17
# 546             tadine -21.5500  167.8833      NC        85
# 547              onega  63.9061   38.1404      RU        96
#
# [548 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon=row["Lng"]
    lat=row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionary
    name_address = requests.get(base_url,params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# adamstown - nearest hotel: No hotel found
# puerto natales - nearest hotel: Dorotea Patagonia Hostel
# la mira - nearest hotel: Hotel La Loma
# bethel - nearest hotel: Hampton Inn Danbury
# port-aux-francais - nearest hotel: Keravel
# bredasdorp - nearest hotel: Victoria Hotel
# stanley - nearest hotel: Hotel 52
# isafjordur - nearest hotel: Hótel Horn
# hawaiian paradise park - nearest hotel: No hotel found
# wonsan - nearest hotel: 원산호텔
# cromer - nearest hotel: Hotel de Paris
# anadyr - nearest hotel: Гостевой дом
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# chinde - nearest hotel: Kanyum cottage village
# klyuchi - nearest hotel: No hotel found
# afaahiti - nearest hotel: Omati Lodge
# tiksi - nearest hotel: Арктика
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# hadibu - nearest hotel: No hotel found
# quinhamel - nearest hotel: No hotel found
# waitangi - nearest hotel: Hotel Chathams
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

vac_map=city_data_df.hvplot.points("Lng", "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    hover_cols = ["Hotel Name", "Country"])
vac_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country)
